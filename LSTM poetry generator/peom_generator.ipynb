# %%
import numpy as np
from gensim.models.word2vec import Word2Vec
import pickle
import os
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import Sequential, LSTM, Dropout, Flatten, Linear, CrossEntropyLoss
import torch.optim.adam

# %% [markdown]
# # data split(insert space between each word)
# 1.   prepare the split dataset for word2vec

# %%
def split_poetry(file = "poetry_5.txt"):
 all_data = open(file, 'r', encoding = 'utf-8').read()
 all_data_split = " ".join(all_data)
 with open("split.txt", 'w', encoding = 'utf-8') as f:
   f.write(all_data_split)
 return all_data.split('\n')

# %% [markdown]
# # Word2Vec convert peom into vector
# 2 version：
# 1.   punctuation exist
# 2.   no punctuation

# %%
# with punctuations
def train_vec(split_file = 'split.txt', org_file = "poetry_5.txt", num_train=300):
  if not os.path.exists('split.txt'):
    split_file = split_poetry()
  org_data = open(org_file, 'r', encoding='utf-8').read().split('\n')[:num_train]
  split_data = open(split_file, 'r', encoding='utf-8').read().split('\n')
  split_data[0] = ' ' + split_data[0]

  model = Word2Vec(split_data, size=128, min_count=1, workers=7)
  #implement word2index based on index2word
  word2index = {token: token_index for token_index, token in enumerate(model.wv.index2word)} 
  return model, org_data, model.syn1neg, model.wv.index2word, word2index

# %%
split_file = 'split.txt'
split_data = open(split_file, 'r', encoding='utf-8').read().split('\n')

# %%
#remove punctuations
def punctuation_remove(file_name):
  file_name = file_name.replace('。','')
  file_name = file_name.replace('，','')
  return file_name

# without punctuations
def train_vec_nopunc(split_file = 'split.txt', org_file = 'poetry_5.txt', train_num=300):
  split_file = split_poetry(file = org_file)
  #remove punctuation in org_data
  org_data = open(org_file, 'r', encoding='utf-8').read()
  org_data = punctuation_remove(org_data)
  org_data = org_data.split('\n')[:train_num]
  #remove punctuation in split_data
  split_data = open(split_file, 'r', encoding='utf-8').read()
  split_data = punctuation_remove(split_data)
  split_data = split_data.split('\n')
  split_data[0] = ' ' + split_data[0]

  model = Word2Vec(split_data, size=128, min_count=1, workers=7)
  #implement word2index based on index2word
  word2index = {token: token_index for token_index, token in enumerate(model.wv.index2word)} 
  return model, org_data, model.syn1neg, model.wv.index2word, word2index

# %% [markdown]
# # data_set
# 1.   all_data: dataset (list)
# 2.   shape of w1:[word_size(number of poems), embedding numbers] which should be [5364, 101]

# %%
class Mydataset(Dataset):
  def __init__(self, all_data, w1, word_2_index, index_2_word ):
    self.w1=w1
    self.word_2_index = word_2_index
    self.all_data = all_data
    self.index_2_word = index_2_word
  
  def __getitem__(self, index):
    a_poetry_words = self.all_data[index]
    a_poetry_index = [self.word_2_index[word] for word in a_poetry_words]
    xs_index = a_poetry_index[:-1]
    ys_index = a_poetry_index[1:]
    xs_embedding = self.w1[xs_index]
    return xs_embedding, np.array(ys_index).astype(np.int64)

  def __len__(self):
    return len(self.all_data)

# %% [markdown]
# # LSTM MODEL

# %%
class lstm_model(nn.Module):
  def __init__(self, embedding_num, hidden_num, word_size):
    super().__init__()
    self.embedding_num = embedding_num
    self.hidden_num = hidden_num
    self.word_size = word_size
    self.lstm = LSTM(input_size = embedding_num, hidden_size=hidden_num, batch_first = True)
    self.model = Sequential(Dropout(0.3),
                            Flatten(0,1),
                            Linear(hidden_num, word_size)
                            )   
    self.cross_entropy = CrossEntropyLoss()
    self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    
  def forward(self, xs_embedding, h_0=None, c_0=None):
    if  h_0 == None and c_0 == None:
      h_0 = torch.tensor(np.zeros((1, xs_embedding.shape[0], self.hidden_num), dtype=np.float32))
      c_0 = torch.tensor(np.zeros((1, xs_embedding.shape[0], self.hidden_num), dtype=np.float32))
    h_0 = h_0.to(self.device)
    c_0 = c_0.to(self.device)
    pre, (h, c) = self.lstm(xs_embedding, (h_0, c_0))
    return self.model(pre), (h, c)

# %% [markdown]
# # auto_generater

# %%
def auto_generater(word_size, model, hidden_num):
  result = ''
  word_index = np.random.randint(0, word_size, 1)[0]
  result += index_2_word[word_index]
  h_0 = torch.tensor(np.zeros((1, 1, hidden_num), dtype=np.float32))
  c_0 = torch.tensor(np.zeros((1, 1, hidden_num), dtype=np.float32))
  for i in range(0, 23):
    word_embeddings = torch.tensor(w1[word_index][None][None])
    pre, (h_0,c_0) = model(word_embeddings, h_0, c_0)
    word_index = int(torch.argmax(pre))
    result += index_2_word[word_index]
  
  return result

# %% [markdown]
# # acrostic_generater
# a verse in which the initial characters of the lines form a word/phrase;

# %%
def acrostic_generater(word_size, model, hidden_num, input_text):
  result = ''
  h_0 = torch.tensor(np.zeros((1, 1, hidden_num), dtype=np.float32))
  c_0 = torch.tensor(np.zeros((1, 1, hidden_num), dtype=np.float32))
  punctuation_list = '，。，。'
  for i in range(0, 4):
    word_index = word_2_index[input_text[i]]
    result+=input_text[i]
    for i in range(0, 4):
      word_embeddings = torch.tensor(w1[word_index][None][None])
      pre, (h_0,c_0) = model(word_embeddings, h_0, c_0)
      word_index = int(torch.argmax(pre))
      result += index_2_word[word_index]
    result += punctuation_list[i]
  return result

# %% [markdown]
# # poem generation

# %%
batch_size =15 #number of words
lr = 0.01 #learning rate
model_vec, all_data, w1, index_2_word, word_2_index = train_vec()
word_size, embedding_num = w1.shape
hidden_num = 51
model = lstm_model(embedding_num, hidden_num, word_size)
data_set = Mydataset(all_data, w1, word_2_index, index_2_word)
data_loader = DataLoader(data_set, batch_size = batch_size)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: Call to deprecated `syn1neg` (Attribute will be removed in 4.0.0, use self.trainables.syn1neg instead).
#   if sys.path[0] == '':

# %%
epochs = 1000
for epoch in range(0, epochs):
  print('--- round {} generation ---'.format(epoch+1))
  for batch_index, (xs_embedding, ys_index) in enumerate(data_loader):
    pre,(h_0, c_0) = model(xs_embedding)
    loss = model.cross_entropy(pre, ys_index.reshape(-1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if batch_index%50==0:
      result = auto_generater(word_size, model, hidden_num)
      print('beautiful chinese 5 words poem:{} loss:{}'.format(result, loss))
# Out:
# --- round 1 generation ---
# beautiful chinese 5 words poem:砥山嗟山山嗟殊山殊拟雷城宁城，，甲城，山，，嗟嗟 loss:8.189482688903809
# --- round 2 generation ---
# beautiful chinese 5 words poem:苓。。，，，。，，，，。，，，，，，，，，。。， loss:6.597034931182861
# --- round 3 generation ---
# beautiful chinese 5 words poem:衲。。。。。，。。。。，，，，。，。。。。，。。 loss:6.6297454833984375
# --- round 4 generation ---
# beautiful chinese 5 words poem:簰，，，，，，。，。。，，，，。，，，，，，，， loss:6.540030002593994
# --- round 5 generation ---
# beautiful chinese 5 words poem:嗟，风，，，，风，，，，，风，，，，，风，风，， loss:6.50416374206543
# --- round 6 generation ---
# beautiful chinese 5 words poem:迎风风，风，风，风风，风，风，，风，风，风，风风 loss:6.3922882080078125
# --- round 7 generation ---
# beautiful chinese 5 words poem:岔海风，风无，，风风无，，风，不，无风，，风风， loss:6.253900051116943
# --- round 8 generation ---
# beautiful chinese 5 words poem:湘风无无，海风风，无风无，，风风无，，不不无，， loss:6.012547969818115
# --- round 9 generation ---
# beautiful chinese 5 words poem:严雨风无，，不无无，，无无无，。不不一，，不不无 loss:5.903372287750244
# --- round 10 generation ---
# beautiful chinese 5 words poem:乳，无无，，风惟无，，风无无，，风无无，。不不无 loss:5.804768085479736
# --- round 11 generation ---
# beautiful chinese 5 words poem:荡海无无外，清海海无人。。不不一。。不海海春，。 loss:5.716853618621826
# --- round 12 generation ---
# beautiful chinese 5 words poem:圜，风无月，，不无无外，。言无无外。。有不无人， loss:5.650660991668701
# --- round 13 generation ---
# beautiful chinese 5 words poem:老风无无，，不一无。。不无海，，不一无人。不言无 loss:5.585433483123779
# --- round 14 generation ---
# beautiful chinese 5 words poem:挑，无风外，清生无一人。不风无无。，不无海人，。 loss:5.546820640563965
# --- round 15 generation ---
# beautiful chinese 5 words poem:水，风无外，风风一海外。不言一海人，相风一无外。 loss:5.4729719161987305
# --- round 16 generation ---
# beautiful chinese 5 words poem:类路无无人，风。无无外，。为无无人，不风无无人， loss:5.42098331451416
# --- round 17 generation ---
# beautiful chinese 5 words poem:老，风无月，今，无无人，清云一无外，不生无无情。 loss:5.400827407836914
# --- round 18 generation ---
# beautiful chinese 5 words poem:摛，惟无外，清风一如，海无无无外。不人一处外，所 loss:5.296793460845947
# --- round 19 generation ---
# beautiful chinese 5 words poem:与雨风海外，南云无上，坐不无海外，不人无处人。相 loss:5.260194301605225
# --- round 20 generation ---
# beautiful chinese 5 words poem:坑，风上外，清风一其人。不生无无外，不意一相情。 loss:5.205121040344238
# --- round 21 generation ---
# beautiful chinese 5 words poem:嶫风无外上，海情无上堂。。。无无外，不人无处人。 loss:5.1880083084106445
# --- round 22 generation ---
# beautiful chinese 5 words poem:耕者无无定，不人一海人。不人无无天，天为意海怍。 loss:5.090890407562256
# --- round 23 generation ---
# beautiful chinese 5 words poem:虞绎无外上，天情一独。。无海海处，清觉无外情。不 loss:5.071755886077881
# --- round 24 generation ---
# beautiful chinese 5 words poem:截矣风外外，安，得一天。不生无谁人，不心无处人。 loss:5.010717868804932
# --- round 25 generation ---
# beautiful chinese 5 words poem:出风风外上，风风一一情。不不无海外，一事无外之。 loss:4.972143650054932
# --- round 26 generation ---
# beautiful chinese 5 words poem:祥者风如上，天云一一情。不言无海外，况拟不虫生。 loss:4.938370227813721
# --- round 27 generation ---
# beautiful chinese 5 words poem:着，外外上，山予负自思。不人无海上，为不无处情。 loss:4.9107232093811035
# --- round 28 generation ---
# beautiful chinese 5 words poem:珪予虫蛸事，不风事林人。相言无无外，清复一天情。 loss:4.901909351348877
# --- round 29 generation ---
# beautiful chinese 5 words poem:耘者惊前外，海天海上情。。日无无上，清意天樽生。 loss:4.797896385192871
# --- round 30 generation ---
# beautiful chinese 5 words poem:娑风无如月，南云海上情。不当环无外，竟意意其人。 loss:4.77935266494751
# --- round 31 generation ---
# beautiful chinese 5 words poem:硖风无如日，天风山嵯香。。海有无外，清意不无情。 loss:4.835668087005615
# --- round 32 generation ---
# beautiful chinese 5 words poem:钻风东无上，天涯一一，。不宵谁人，清意一处情。不 loss:4.804804801940918
# --- round 33 generation ---
# beautiful chinese 5 words poem:昭者风轮日，海不静草，人人上处上，愁义岂相春。不 loss:4.735459804534912
# --- round 34 generation ---
# beautiful chinese 5 words poem:览者无声坼，海花一一山。不人无海外，清不一相情。 loss:4.697521209716797
# --- round 35 generation ---
# beautiful chinese 5 words poem:丽者无无上，天风海上情。。日肯尚客，清事一灯人。 loss:4.667995929718018
# --- round 36 generation ---
# beautiful chinese 5 words poem:鸢鹤风声山，天风上上上。。人为无外，清事无外情。 loss:4.605762004852295
# --- round 37 generation ---
# beautiful chinese 5 words poem:徂风无无外，风上意熟情。。因无无限，幽复博已删。 loss:4.611424922943115
# --- round 38 generation ---
# beautiful chinese 5 words poem:馨风无无外，天涯不处天。一人犹无外，明与有何情。 loss:4.587036609649658
# --- round 39 generation ---
# beautiful chinese 5 words poem:颷叶风丹青，南风一一驰。不人无海外，怜予一窒春。 loss:4.5700459480285645
# --- round 40 generation ---
# beautiful chinese 5 words poem:栩公无无坼，交云咏一里。不生无海外，清日泪征，潮 loss:4.593727111816406
# --- round 41 generation ---
# beautiful chinese 5 words poem:翽者故三事，不情一上人。不因托一外，幽与意无枫。 loss:4.522457599639893
# --- round 42 generation ---
# beautiful chinese 5 words poem:妙，外风早，留客事未沚。岁方扶履财，坐惜岂相春。 loss:4.428041458129883
# --- round 43 generation ---
# beautiful chinese 5 words poem:娟白交能偶，冰，海外外，相云得慰色，清因犹相杂， loss:4.422257900238037
# --- round 44 generation ---
# beautiful chinese 5 words poem:悚者贵冥外，中涯一外人。不人肯谁然，旷卉可可春。 loss:4.400704860687256
# --- round 45 generation ---
# beautiful chinese 5 words poem:鸯风无冰鼓，愿柏趁所谋。岁来犹海外，。滨无无，。 loss:4.437390327453613
# --- round 46 generation ---
# beautiful chinese 5 words poem:灊，外肯坼，心涯憔不人。不犹仍幽独，不稍讯笙嘉。 loss:4.417967319488525
# --- round 47 generation ---
# beautiful chinese 5 words poem:甚者无轮远，何涯一上障。一光向已楚，况雾岂相春。 loss:4.365878105163574
# --- round 48 generation ---
# beautiful chinese 5 words poem:酲风非无夕，向绎客其贫。岁歌犹无杂，不话亦其情。 loss:4.353238105773926
# --- round 49 generation ---
# beautiful chinese 5 words poem:贔者无声郭，心色向情寻。相园仍过折，不意一无如。 loss:4.384316444396973
# --- round 50 generation ---
# beautiful chinese 5 words poem:牖风无无鸟，海涯乐不秋。何宵慰可陵，不意无外边。 loss:4.328227996826172
# --- round 51 generation ---
# beautiful chinese 5 words poem:阚露无涯夕，数玄鹤一沚。所生潇为法，余望梦何人。 loss:4.2504987716674805
# --- round 52 generation ---
# beautiful chinese 5 words poem:聘汉及洞斗，清筠山嵯疆。此识犹无外，疏与不相诗。 loss:4.211826801300049
# --- round 53 generation ---
# beautiful chinese 5 words poem:桐公无涯夕，数客静凄人。虚生犹谁来，留与一如如。 loss:4.245297431945801
# --- round 54 generation ---
# beautiful chinese 5 words poem:追我逢无外，宁色一夜峦。。日天差宿，一日海外加。 loss:4.130484104156494
# --- round 55 generation ---
# beautiful chinese 5 words poem:汀者无丹雪，心向落上涯。当言犹一外，愁复凤相醺。 loss:4.207601070404053
# --- round 56 generation ---
# beautiful chinese 5 words poem:泻方贵麟白，萧逸煅蛎操。岁怜无霜在，清滨均床侣。 loss:4.247300148010254
# --- round 57 generation ---
# beautiful chinese 5 words poem:浣拙诸蛸月，诛逸可转贫。岁心无海上，孤与意限泉。 loss:4.290625095367432
# --- round 58 generation ---
# beautiful chinese 5 words poem:亿客贪陀叶，天年竹一人。雨歌镇相身，树云共令诗。 loss:4.1854634284973145
# --- round 59 generation ---
# beautiful chinese 5 words poem:灵落初弦鼓，风声袭落思。不人肯玩种，不事扶丝方。 loss:4.222391605377197
# --- round 60 generation ---
# beautiful chinese 5 words poem:枰露当长鬓，冰云咏相思。相中环来意，愁义凤斜。声 loss:4.153643608093262
# --- round 61 generation ---
# beautiful chinese 5 words poem:聱民无上鸟，胡与漫斜耶。余公犹海上，留与意弟功。 loss:4.034423351287842
# --- round 62 generation ---
# beautiful chinese 5 words poem:偃者浑架客，迷檄翰墨，安谁似相生。所人一海上，向 loss:4.09441614151001
# --- round 63 generation ---
# beautiful chinese 5 words poem:磅路心林坼，同潮似汝奇。三公离幽逝，含壑寸可支。 loss:4.092442989349365
# --- round 64 generation ---
# beautiful chinese 5 words poem:庭者东如定，数声惨江毡。谓言无无觅，不话讯潺，风 loss:4.058965682983398
# --- round 65 generation ---
# beautiful chinese 5 words poem:惬者无初坼，胡当自称稗。不园程古独，更日博茑迁。 loss:3.9995229244232178
# --- round 66 generation ---
# beautiful chinese 5 words poem:锐碕无外早，王染独不微。。雨海停客，清柯戬板关。 loss:4.038835525512695
# --- round 67 generation ---
# beautiful chinese 5 words poem:球蔗寄无彼，心朝惨夜洲。岁中秋浅候，不日一限父。 loss:4.007354736328125
# --- round 68 generation ---
# beautiful chinese 5 words poem:槟题诸风露，崩纹失自谋。北生尊白鸟，篝复任不春。 loss:3.906255006790161
# --- round 69 generation ---
# beautiful chinese 5 words poem:差拙无无饥，心色别未松。不人宵来宿，常酒旧相醺。 loss:3.9722163677215576
# --- round 70 generation ---
# beautiful chinese 5 words poem:隍路无霞水，清上意上情。南生翔念缴，不话亦病荧。 loss:3.9971604347229004
# --- round 71 generation ---
# beautiful chinese 5 words poem:徇风无冰茏，庭云咏子工。所识眺幽颅，不郭蓑谓支。 loss:3.8554744720458984
# --- round 72 generation ---
# beautiful chinese 5 words poem:骁歌无缓雨，襁忆独争行。虚哉无尝钵，不话铁郫通。 loss:3.886789083480835
# --- round 73 generation ---
# beautiful chinese 5 words poem:债风蛮弦月，风延负射翁。不端何海外，高与慰襟悬。 loss:3.8583245277404785
# --- round 74 generation ---
# beautiful chinese 5 words poem:嵯迹无前坼，数笏远慨间。相哉镇溽兵，幽识野禁心。 loss:3.8366684913635254
# --- round 75 generation ---
# beautiful chinese 5 words poem:洋叶鱼孤梦，裁方君碊耕。余朝应谁访，不意泪萧梅。 loss:3.8808982372283936
# --- round 76 generation ---
# beautiful chinese 5 words poem:廉簟幽风早，隔暇失汝阑。。头过慰风，人净客后情。 loss:3.901427984237671
# --- round 77 generation ---
# beautiful chinese 5 words poem:拳派风意早，隔客我未贫。不人鎔投种，相身故芝堆。 loss:3.881430149078369
# --- round 78 generation ---
# beautiful chinese 5 words poem:车公无缓垂，庭味忽碊。。如向谁处人，竟见未无凉。 loss:3.858106851577759
# --- round 79 generation ---
# beautiful chinese 5 words poem:澎岁尊熳鸣，萧云慰翠尘。所生环海上，坐柯不泽迷。 loss:3.7875895500183105
# --- round 80 generation ---
# beautiful chinese 5 words poem:瘳拙无缓翦，宁慽酒命嗟。南中无雁纪，不惜野沈埃。 loss:3.814852237701416
# --- round 81 generation ---
# beautiful chinese 5 words poem:介幡既孤人，孤事夜里，山置色海情。坐时环芗腥，幽 loss:3.7426860332489014
# --- round 82 generation ---
# beautiful chinese 5 words poem:渎苗东郑稽，袭柏仲蔚脾。何识何处好，山乃故不举。 loss:3.7716963291168213
# --- round 83 generation ---
# beautiful chinese 5 words poem:夫菽飘筵碧，神枝钟重话。下中翔比在，清事一仞疏。 loss:3.7975080013275146
# --- round 84 generation ---
# beautiful chinese 5 words poem:忆萝东人饥，丝玄压蜜脾。筹方频无人，留与夜仞愁。 loss:3.690089225769043
# --- round 85 generation ---
# beautiful chinese 5 words poem:抿山初盐爽，和圃力蛎跃。下识犹谁蕊，入意散萧蓉。 loss:3.7970213890075684
# --- round 86 generation ---
# beautiful chinese 5 words poem:苇者迎厨远，捧檄但咄雒。半心犹镞业，顿食意可举。 loss:3.680689811706543
# --- round 87 generation ---
# beautiful chinese 5 words poem:自中频看月，南色一亩宫。当生尊幼疏，茅客学春欤。 loss:3.666775941848755
# --- round 88 generation ---
# beautiful chinese 5 words poem:郫华无缓翦，清襟订于鸣。眷言还豚源，更日梦再甘。 loss:3.7019760608673096
# --- round 89 generation ---
# beautiful chinese 5 words poem:驺衍既痕德，今法顾于颠。不识环蚩舆，宸壑芦笙卖。 loss:3.7199628353118896
# --- round 90 generation ---
# beautiful chinese 5 words poem:聘然涉迤者，僧忆鲍参跃。所闻谢履颓，缘勿伫禅灭。 loss:3.6690382957458496
# --- round 91 generation ---
# beautiful chinese 5 words poem:鞺者逶架飓，匏云早子于。日端无宵候。更来迫芗户， loss:3.631503105163574
# --- round 92 generation ---
# beautiful chinese 5 words poem:裳簟高吾争，若云别儡雪。醍哉紫履赏，胜觉棠新虫。 loss:3.5702264308929443
# --- round 93 generation ---
# beautiful chinese 5 words poem:鸦露风缓蛰，千贻亦草雪。所知应纤种，愿觉结心呈。 loss:3.5834550857543945
# --- round 94 generation ---
# beautiful chinese 5 words poem:酱火贪架鼓，报云傀儡肥。既闻犹无海，草客不仞长。 loss:3.582791566848755
# --- round 95 generation ---
# beautiful chinese 5 words poem:饿者当无赖，王乔酒扬霜。坐生犹摇访，不有有寂父。 loss:3.5306003093719482
# --- round 96 generation ---
# beautiful chinese 5 words poem:榖辉风缓翦，墨辞力簟期。夹禄完可乐，陈蠢尔轻加。 loss:3.6046454906463623
# --- round 97 generation ---
# beautiful chinese 5 words poem:蚪已无葱徼，还虎竹并瀣。坐崦玷使穴，予词刀景踱。 loss:3.5523600578308105
# --- round 98 generation ---
# beautiful chinese 5 words poem:岘路常逭山，风必负逆船。下性姜已颅，应日泪襟醺。 loss:3.60758113861084
# --- round 99 generation ---
# beautiful chinese 5 words poem:迹绎汇洞鹿，齿翼革翘窑。可哉连良庭，烂此意情。机 loss:3.555262565612793
# --- round 100 generation ---
# beautiful chinese 5 words poem:蜘拙重杠火，浪忆妄蛎附。虚无无处好，不解剩桑悔。 loss:3.534729242324829
# --- round 101 generation ---
# beautiful chinese 5 words poem:总檐风前坼，同窗树有。深心一摇然。遭蕃频窈息，巴 loss:3.59039044380188
# --- round 102 generation ---
# beautiful chinese 5 words poem:哨乡无缓翦，饕絙可一逢。。俱浓十纹，更队醉书踱。 loss:3.4461371898651123
# --- round 103 generation ---
# beautiful chinese 5 words poem:鲕秋初不夏，冰状几兹辰。谓言耽无外，矍铄每经关。 loss:3.461524486541748
# --- round 104 generation ---
# beautiful chinese 5 words poem:搔露七作佛，离者仗相奇。冰掠无兹闭，粗濯似图眉。 loss:3.4598023891448975
# --- round 105 generation ---
# beautiful chinese 5 words poem:讼坦村何事，开军落漈峦。不因无妨宿，烦节各如菜。 loss:3.424952268600464
# --- round 106 generation ---
# beautiful chinese 5 words poem:戚露亦前坼，丝，挟狂疏。抚方忍颜错，幽日白弗届。 loss:3.4852852821350098
# --- round 107 generation ---
# beautiful chinese 5 words poem:根木重御状，谭空玩积葽。所老犹兹，前绝鴒转真。平 loss:3.383192777633667
# --- round 108 generation ---
# beautiful chinese 5 words poem:县秋涉架群，顶踵羱角端。如歌双皇纹，幽汐醉素力。 loss:3.459319829940796
# --- round 109 generation ---
# beautiful chinese 5 words poem:旋绎无前重，噬云思悴同。无樽机慰泻，茅节结相蘀。 loss:3.4339001178741455
# --- round 110 generation ---
# beautiful chinese 5 words poem:堞落无葱茏，宁诗仗暮堂。一日肯比历，相话亦相度。 loss:3.464099645614624
# --- round 111 generation ---
# beautiful chinese 5 words poem:露汉风坡坼，噬云挟狂。幽戏无锦臞。沅衣还敢处，文 loss:3.5226852893829346
# --- round 112 generation ---
# beautiful chinese 5 words poem:费幡君吾密，繁用岂防贤。无人宵玩晋，宸词岂可神。 loss:3.4668514728546143
# --- round 113 generation ---
# beautiful chinese 5 words poem:准岭复迢遰，油絙废重裳。震蹶固啸荡，问意透寂美。 loss:3.415044069290161
# --- round 114 generation ---
# beautiful chinese 5 words poem:闽田既藓急，陌翼煅蛎，下襟慰吟猱。柴槛推曲色，风 loss:3.4360740184783936
# --- round 115 generation ---
# beautiful chinese 5 words poem:义华重阳私，卵目蜥蜴奇。岁辉无海上，远豁病林槎。 loss:3.374258279800415
# --- round 116 generation ---
# beautiful chinese 5 words poem:金然贵陀山，城适想笼予。白堪双椠饥，风草慰窒人。 loss:3.4044837951660156
# --- round 117 generation ---
# beautiful chinese 5 words poem:约拙非前愿，终客惨澹牙。昔渚鲸蚩阵，弱引受新踱。 loss:3.3259451389312744
# --- round 118 generation ---
# beautiful chinese 5 words poem:杨火无人赖，潮乔似生稀。羡书验相分，更日托相论。 loss:3.3545470237731934
# --- round 119 generation ---
# beautiful chinese 5 words poem:楚我常厨具，谭风片举肥。乃哉还径者，文然二相关。 loss:3.3700954914093018
# --- round 120 generation ---
# beautiful chinese 5 words poem:参耕龙稽陌，喧观渡一沚。远识心处觅，劲枭翼苔眉。 loss:3.417085647583008
# --- round 121 generation ---
# beautiful chinese 5 words poem:膝风国荐具，谭持檐未雨。岛心茶灶，上高卧双风气。 loss:3.3934223651885986
# --- round 122 generation ---
# beautiful chinese 5 words poem:薇者出且珪，巴将泪未于。当人翔共宠，入惜扶犵狫。 loss:3.3196098804473877
# --- round 123 generation ---
# beautiful chinese 5 words poem:鰕客无安鸟，数笏钟争回。。天浅比伤流。白橙幽泪涉 loss:3.296621322631836
# --- round 124 generation ---
# beautiful chinese 5 words poem:忒触交臾冥，卵零仲蛎附。柴蹶鞭末氓，毒引尚菉眉。 loss:3.309739828109741
# --- round 125 generation ---
# beautiful chinese 5 words poem:薝能缑蛸是，同上事欢嗟。官车仍及息，遥聚白如枫。 loss:3.250380277633667
# --- round 126 generation ---
# beautiful chinese 5 words poem:边白逢如外，爱眼每恢操。岁人应镞业，不敌野登伤。 loss:3.3018136024475098
# --- round 127 generation ---
# beautiful chinese 5 words poem:鹄蔗田稽灶，卵云蜃教在。半心沧海足，千谷趁韭薤。 loss:3.267700433731079
# --- round 128 generation ---
# beautiful chinese 5 words poem:拨色入无敌，杏际动不稀。不生走洒楚，不乃野禁瘵。 loss:3.308840751647949
# --- round 129 generation ---
# beautiful chinese 5 words poem:面叶托无极，鸡唱竹泽凶。昔香鞭为面，榴世谱清菜。 loss:3.2959275245666504
# --- round 130 generation ---
# beautiful chinese 5 words poem:凸者飞逭续，蔬叶鞭诗硌。余坐一使足，鸥对欲自加。 loss:3.4610016345977783
# --- round 131 generation ---
# beautiful chinese 5 words poem:迎潮初无冠，腊诗事汝同。无因浓皇壤，更汐野可加。 loss:3.5661728382110596
# --- round 132 generation ---
# beautiful chinese 5 words poem:木路浑逭陌，春风早栩自。桶裙能伴制，那词窥虞衡。 loss:3.3359367847442627
# --- round 133 generation ---
# beautiful chinese 5 words poem:罚汉外涯坼，胡染力所群。朅魅依鼍馆，相日悉足美。 loss:3.2837274074554443
# --- round 134 generation ---
# beautiful chinese 5 words poem:态公飘风朗，崩者愧餐美。鹤疏秋停色，绝铄木相关。 loss:3.219170331954956
# --- round 135 generation ---
# beautiful chinese 5 words poem:焰白风葱茏，风泻自轻。举勿还怅古，淜滂殷颓关。三 loss:3.326507329940796
# --- round 136 generation ---
# beautiful chinese 5 words poem:衫拙卵衣茹，蛮喧身贱改。所心应无在，留泛动乡丛。 loss:3.130633592605591
# --- round 137 generation ---
# beautiful chinese 5 words poem:觥辉复贞李，谭观趣阴经。柴绩能川除，稍雾任回洲。 loss:3.1524367332458496
# --- round 138 generation ---
# beautiful chinese 5 words poem:烘华亦氏灵，松然犹霭雪。半中犹念坐，头申蓑缠谙。 loss:3.330775260925293
# --- round 139 generation ---
# beautiful chinese 5 words poem:问山逢寿觥，故岐订卜鸣。卖疏聊无外，啼义众颓台。 loss:3.1591107845306396
# --- round 140 generation ---
# beautiful chinese 5 words poem:济蛮复古豪，因，俱玩雒。如期尚幽者，白厚了笠至。 loss:3.1805312633514404
# --- round 141 generation ---
# beautiful chinese 5 words poem:甸龙无声展，恣与愧聱传。昭湍完无声，猿泛佐谓起。 loss:3.110243320465088
# --- round 142 generation ---
# beautiful chinese 5 words poem:参乡飘弦密，中风趣迟城。坐畦岁佛翦，相敌二犵谙。 loss:3.0568735599517822
# --- round 143 generation ---
# beautiful chinese 5 words poem:栢路常逭暑，清襟照栩嗟。还规无闻鸟，谁与一外边。 loss:3.106727361679077
# --- round 144 generation ---
# beautiful chinese 5 words poem:赓萝煎奸回，怀间访，紫情。如帘不处橘。佛生涤投脚 loss:3.2014622688293457
# --- round 145 generation ---
# beautiful chinese 5 words poem:蹋者入葱得，庭柏但咄错。虚盆推添纹，犁锸任时。触 loss:3.114908218383789
# --- round 146 generation ---
# beautiful chinese 5 words poem:壤簟蓣古立，蛮者逃后陵。下云泪幼腥，不意散和诗。 loss:3.1115176677703857
# --- round 147 generation ---
# beautiful chinese 5 words poem:硖萝汇洞者，城迟野湖更。妙人扶异警，残览讯弓侣。 loss:3.046657085418701
# --- round 148 generation ---
# beautiful chinese 5 words poem:肢客鱼无许，鸡声万席。幽计无宵翠客，羇节已弥台。 loss:3.1015684604644775
# --- round 149 generation ---
# beautiful chinese 5 words poem:鴂霍理令立，蓬颻翰霭操。昭湍鹭蓼祖，养戏指登轻。 loss:3.2682220935821533
# --- round 150 generation ---
# beautiful chinese 5 words poem:面者风轮鸟，襁者不故知。所人翔皇缴，不览振素支。 loss:3.2140469551086426
# --- round 151 generation ---
# beautiful chinese 5 words poem:诡我心齿展，顾虎均空寻。朅物验末诘，应物语蔬瘵。 loss:3.147953748703003
# --- round 152 generation ---
# beautiful chinese 5 words poem:榖须无要翦，伤漏恣簟昏。冰纨澄无意，披滞对上山。 loss:3.1442248821258545
# --- round 153 generation ---
# beautiful chinese 5 words poem:奠幡田臾骥，问敢癸庚栩。布方下过之，天卑铁榖赓。 loss:3.1311230659484863
# --- round 154 generation ---
# beautiful chinese 5 words poem:鲛莽田功侄，蔗泉寄瞻荆。妙手栽阶吼，海滨履王土。 loss:3.2389984130859375
# --- round 155 generation ---
# beautiful chinese 5 words poem:贩岭细迢骥，旋床煅三经。细福固可下，幽不博郫美。 loss:3.0922203063964844
# --- round 156 generation ---
# beautiful chinese 5 words poem:儡火无涯赖，终径鹤自群。曷酿还无如，坐厚每强槎。 loss:3.0346970558166504
# --- round 157 generation ---
# beautiful chinese 5 words poem:蕴簟煎布私，卵愆煅蔚窑。柴质澄无亏，鸱枭岂孔起。 loss:3.0084376335144043
# --- round 158 generation ---
# beautiful chinese 5 words poem:伸公秉架德，匏翼渡汉贤。逆店阒无啸，猿章印各。蔬 loss:3.0089032649993896
# --- round 159 generation ---
# beautiful chinese 5 words poem:瞰予逾作饭，俭用石霭期。小哉漾摩纹，犁锸结生庚。 loss:3.0939788818359375
# --- round 160 generation ---
# beautiful chinese 5 words poem:重雨逢荐似，天南袭落涯。离香狎戟诘，汲为无其荧。 loss:3.0707013607025146
# --- round 161 generation ---
# beautiful chinese 5 words poem:囊公麒脯选，摧餐餮霭邻。可影潇洒泻，应园葛壶颐。 loss:3.0093600749969482
# --- round 162 generation ---
# beautiful chinese 5 words poem:参琐逾正茹，悬风正子辉。还公犹岫豫，独队读螺衡。 loss:2.968642473220825
# --- round 163 generation ---
# beautiful chinese 5 words poem:耸触既正佛，蔗维煅蛎窑。下有应音访，幽笑或相津。 loss:3.1272332668304443
# --- round 164 generation ---
# beautiful chinese 5 words poem:体存尚蝘隐，蔗融煅蛎期。可闻悬幼制，稍锸得忘车。 loss:3.1681952476501465
# --- round 165 generation ---
# beautiful chinese 5 words poem:鼓风蛮蜑月，城子钟伊疆。渴虹淹壑荒，只解结代眉。 loss:3.0998899936676025
# --- round 166 generation ---
# beautiful chinese 5 words poem:裾幡既作崖生神，力增酒澎霜。异池而摩息，又事贮层 loss:3.1188418865203857
# --- round 167 generation ---
# beautiful chinese 5 words poem:妍者尊翼群，率寐煅蛎操。如人鎔双，，向义怅庭人。 loss:3.1038150787353516
# --- round 168 generation ---
# beautiful chinese 5 words poem:溆马无杠坼，梅云咏色思。岁秋潇灶卜，予背拔荫碎。 loss:3.0493662357330322
# --- round 169 generation ---
# beautiful chinese 5 words poem:残视莺遗桂，青熟一欢深。香榔围可惜，猿转芦茅鞍。 loss:2.8831465244293213
# --- round 170 generation ---
# beautiful chinese 5 words poem:狰我估前远，清涯向觉愁。所怜更海外，宾客故悲同。 loss:2.9879539012908936
# --- round 171 generation ---
# beautiful chinese 5 words poem:醹白悬泓爽，喧田剩阴改。岁识犹使色，疏然橘酒醺。 loss:3.070060968399048
# --- round 172 generation ---
# beautiful chinese 5 words poem:初秋逢寿续，摧湖忆所渡。岁身环少法，顿稍不用扬。 loss:2.986098051071167
# --- round 173 generation ---
# beautiful chinese 5 words poem:小顾蠢节楫，浮陬竹逆操。醍虹淹荆议，毒壑虔茅粝。 loss:3.0300521850585938
# --- round 174 generation ---
# beautiful chinese 5 words poem:勉公及脯茄，俭云傀儡嗟。。中斁慰幽土，何滨故其狫 loss:3.052675247192383
# --- round 175 generation ---
# beautiful chinese 5 words poem:纛萝亲衢挈，竭蓁感水汰。妙掠还须籴，按寒泪点条。 loss:3.0794575214385986
# --- round 176 generation ---
# beautiful chinese 5 words poem:悠拙质帝溟，青延早等同。半当无少好，际逐均古。厥 loss:2.9704859256744385
# --- round 177 generation ---
# beautiful chinese 5 words poem:朓霍蠨蛸树，裁炙任夕身。朅福还养信，按响惟阑桐。 loss:2.924513101577759
# --- round 178 generation ---
# beautiful chinese 5 words poem:殊茅菉至涉，遥衢妄谷荒。平筵醉陋错，豆锸应风外。 loss:3.046523332595825
# --- round 179 generation ---
# beautiful chinese 5 words poem:忙耕苔湖崖，俭茝浑自俦。不生貌纤鼓，宸逐特代芥。 loss:2.9702658653259277
# --- round 180 generation ---
# beautiful chinese 5 words poem:篱俗无缓翦，蔬餮石却有。手蕃近阶制，愁异讯琐空。 loss:3.078430414199829
# --- round 181 generation ---
# beautiful chinese 5 words poem:董者重前殊，巴者事渐块。泉簇悬良纹，舍谬结琐颐。 loss:3.0511884689331055
# --- round 182 generation ---
# beautiful chinese 5 words poem:久予澎提逮，清筠合院回。醍禽能兹赏，舍队指菉眉。 loss:2.9452037811279297
# --- round 183 generation ---
# beautiful chinese 5 words poem:正乡蘧孤饭，通餐羱独同。蛮店聊蓼氏，应巷尔螺衡。 loss:3.4897491931915283
# --- round 184 generation ---
# beautiful chinese 5 words poem:肚鸸无缓翦，墨云榕秀暮。虚零鳌溽议，底豚意新枫。 loss:3.382927179336548
# --- round 185 generation ---
# beautiful chinese 5 words poem:罴待飘儿续，司餐渡霭栩。可识翔无在，辗复对弥衣。 loss:3.1846604347229004
# --- round 186 generation ---
# beautiful chinese 5 words poem:笛耕重能树，松柏失禅空。菊心沧无外，孤吹暗钓皇。 loss:2.9807989597320557
# --- round 187 generation ---
# beautiful chinese 5 words poem:涧露对火远，独举伏苍苔。北香沧处上，胜与任艰台。 loss:2.969897747039795
# --- round 188 generation ---
# beautiful chinese 5 words poem:宫露飘令照，报舸困角传。冰户能蓼除，平队了笠衡。 loss:2.932685136795044
# --- round 189 generation ---
# beautiful chinese 5 words poem:伊拙东郑重，饕虎细失端。倚店聊啸然，豳属尤狡狯。 loss:2.9400081634521484
# --- round 190 generation ---
# beautiful chinese 5 words poem:陨迹无缓翦，噬讨失蔚予。顷质虔息鹭，风庥桃万。啼 loss:2.904512882232666
# --- round 191 generation ---
# beautiful chinese 5 words poem:望食揽难路，灯老利星盟。异人走异腥，伏飓芦粗嘉云 loss:2.888059139251709
# --- round 192 generation ---
# beautiful chinese 5 words poem:帡然非无赖，寻亲棹不挥。不载亦海外，竟吹息艰私。 loss:2.760829448699951
# --- round 193 generation ---
# beautiful chinese 5 words poem:丈忍及古事，崩志革有谋。不涕亦须馆，幽衣粉琐颐。 loss:2.796360969543457
# --- round 194 generation ---
# beautiful chinese 5 words poem:氲鹤持麟茄，野纹均碊林。题须明谁辟，不恬度瑟埃。 loss:2.835186719894409
# --- round 195 generation ---
# beautiful chinese 5 words poem:及传还蛸外，杨柳拂蜜编。昭质澄蓼回，榔尚料处尘。 loss:2.8894951343536377
# --- round 196 generation ---
# beautiful chinese 5 words poem:巍楚须吾妇，蛮际野自身。暂怡酬州暑，旷锋读中流社 loss:2.894151210784912
# --- round 197 generation ---
# beautiful chinese 5 words poem:拊存仲冥回，怀户劳蛈蟷。将福眺及色，宾泻搘禅关。 loss:2.944859266281128
# --- round 198 generation ---
# beautiful chinese 5 words poem:埴客非笼道，秀柏趁生戒。召爵若缥源，愁日白弗父。 loss:2.863342761993408
# --- round 199 generation ---
# beautiful chinese 5 words poem:俱拙苔节道，双尔均溪俦。震枭若师馆，貎日记令顾。 loss:2.931039571762085
# --- round 200 generation ---
# beautiful chinese 5 words poem:像苗尚如若，崩角革重贞。北木无渔晚，徒御困钟各。 loss:2.798405170440674
# --- round 201 generation ---
# beautiful chinese 5 words poem:砥幡及布期，怀怜劳水空。米手无无直，疑葵何亦局。 loss:3.000957489013672
# --- round 202 generation ---
# beautiful chinese 5 words poem:直公无名坼，伤染喜角。。花避镇尘首，触望分峨关。 loss:2.8880529403686523
# --- round 203 generation ---
# beautiful chinese 5 words poem:叟饱田功妇，荆蓁煅蛎窑。柴古耽纪在，荆直尤颓台。 loss:2.9348976612091064
# --- round 204 generation ---
# beautiful chinese 5 words poem:黔者贵迤远，迷间合龙愕。万才蚩曲折，应情学相筒。 loss:2.9259188175201416
# --- round 205 generation ---
# beautiful chinese 5 words poem:榔萋尚右骥，卵用讼兰窑。下方低窄簟，他锸搘琐鹤。 loss:2.8560993671417236
# --- round 206 generation ---
# beautiful chinese 5 words poem:夸发无流雨，性笏鴒故生。事暗针幽壤，嬉戏读独衡。 loss:2.814730405807495
# --- round 207 generation ---
# beautiful chinese 5 words poem:桑叶贪蜑喧，顶泉思贱驯。万方憺过啜，悠影怅公形。 loss:2.8358042240142822
# --- round 208 generation ---
# beautiful chinese 5 words poem:搽友蒲提庭，杯然寄殊翁。妙术六蓼然，端为梦夏贤。 loss:2.8157718181610107
# --- round 209 generation ---
# beautiful chinese 5 words poem:洵簟龙田挈，樯马犹贱翁。举遍无舂闭，无乃盭窒望。 loss:2.8426318168640137
# --- round 210 generation ---
# beautiful chinese 5 words poem:菩沙村麟密，清仍忆阴召。倚方频深二，尺寸志两车。 loss:2.7780425548553467
# --- round 211 generation ---
# beautiful chinese 5 words poem:灭俗及前事，呼予力断蓬。快方聊缥桂，送逐诉可通。 loss:2.8159878253936768
# --- round 212 generation ---
# beautiful chinese 5 words poem:墉幡及作崖，若志亦扬贤。平妨姜縠纹，将汐讯弓篱。 loss:2.8625802993774414
# --- round 213 generation ---
# beautiful chinese 5 words poem:糖汉涉奸舍，匏愆煅蛎窑。喧嚣聊添簟，那锸蜥清海。 loss:2.8347179889678955
# --- round 214 generation ---
# beautiful chinese 5 words poem:胯友汇洞庭，深尔落露忘。香慎了将兵，凉觉挥荫解。 loss:2.8672056198120117
# --- round 215 generation ---
# beautiful chinese 5 words poem:状题君火隐，争叶桑然思。岁岸悬拉苔，庭单拔狡征。 loss:2.884024143218994
# --- round 216 generation ---
# beautiful chinese 5 words poem:漉华出葱得，留摘但碊林。柴囚无施闭，涩意振寂美。 loss:2.8396217823028564
# --- round 217 generation ---
# beautiful chinese 5 words poem:渊望观笼梦，支雄攒墨晴。要策详可曲，犹见对峨裾。 loss:2.8742454051971436
# --- round 218 generation ---
# beautiful chinese 5 words poem:朝宵普难急，繁嗑沓相在。圆魄能壑望，赴滂意由间。 loss:2.7238292694091797
# --- round 219 generation ---
# beautiful chinese 5 words poem:藁霍兕廌立，浮籍均乳附。公念无舂闭，问滑醉古空。 loss:2.8913536071777344
# --- round 220 generation ---
# beautiful chinese 5 words poem:鎔者似笼群，中庭座阴堂。官云沧浅色，疏滂忽尘春。 loss:2.6946189403533936
# --- round 221 generation ---
# beautiful chinese 5 words poem:穴浮伽前冠，族嗑事忽现。参绩频及叩，入馔搘犵，将 loss:2.833941698074341
# --- round 222 generation ---
# beautiful chinese 5 words poem:萋迹蓣儿御，匏愆似兰。平清媚颜郡，只客得松桓。坐 loss:2.68796706199646
# --- round 223 generation ---
# beautiful chinese 5 words poem:尊萝无涯缝，去意是客花。飓魅虔拜阵，毒壑美踱鞍。 loss:2.779252529144287
# --- round 224 generation ---
# beautiful chinese 5 words poem:期湖逢轮楫，陈餐愧微酬竹。相帘镇施岐，阅湘刀阳轻 loss:2.7145354747772217
# --- round 225 generation ---
# beautiful chinese 5 words poem:翅马还嘘常，司云蜃异鳞。。花憺镇缴，曷蠢刀剑。古 loss:2.720761775970459
# --- round 226 generation ---
# beautiful chinese 5 words poem:耶鹤非嘘李，司絙喜瞻荆。召蹶耽舄涉，把迹凤容征。 loss:2.737326145172119
# --- round 227 generation ---
# beautiful chinese 5 words poem:圄和及乐茄，俭冬蜥杙俦。平识符楚历，市物薋情声。 loss:2.704390525817871
# --- round 228 generation ---
# beautiful chinese 5 words poem:曹幡甲似冥，蛮茝散大。况唼怡泽人共。岁湘葛刀香。 loss:2.7307586669921875
# --- round 229 generation ---
# beautiful chinese 5 words poem:然楼风前劲，潮深静先微。勿人橙纤种，幽惜亦公荧。 loss:2.7984540462493896
# --- round 230 generation ---
# beautiful chinese 5 words poem:鑱哳愁御幡，油子卖改间。半规升毅惜，民聚约螺衣。 loss:2.8734421730041504
# --- round 231 generation ---
# beautiful chinese 5 words poem:伛和重蹊眼，顾絙蜥不堂。半诗扶为许，养葵流无池。 loss:2.700603723526001
# --- round 232 generation ---
# beautiful chinese 5 words poem:屧触亦长笛，恣声幸至夕。。滨帘慰影，旷与任图悬。 loss:2.838651418685913
# --- round 233 generation ---
# beautiful chinese 5 words poem:甓饮宜如早，因与欲一楼。捕移骄养土，微为备层颜。 loss:2.653090000152588
# --- round 234 generation ---
# beautiful chinese 5 words poem:杠歌喜难夜，畬柏困凉来。泉处侍洒楚，弱熳为虎车。 loss:2.7311453819274902
# --- round 235 generation ---
# beautiful chinese 5 words poem:耜刀门如术，达云买平寻。逆掠指无属，毋葵看虎兕。 loss:2.773522138595581
# --- round 236 generation ---
# beautiful chinese 5 words poem:脑黄重嘘树，依檄独笼邈。平园铅师吼，予日俱令过。 loss:2.7861671447753906
# --- round 237 generation ---
# beautiful chinese 5 words poem:熙公鹅受间，衰摘困漠门。要囚鳌溽议，弱讴窥寸眉。 loss:2.7106943130493164
# --- round 238 generation ---
# beautiful chinese 5 words poem:纡提屯蝘飓，蔗用拟蔚脾。倚掠下无啸，恩物一初兄。 loss:2.76542067527771
# --- round 239 generation ---
# beautiful chinese 5 words poem:翮萝汇洞选，浑踵檐兰塞。晋堪犹无鸟，常宦或睡粝。 loss:2.855363607406616
# --- round 240 generation ---
# beautiful chinese 5 words poem:箨废饭奸回，怀阗劳角英。下光符令诚，更有望围尘。 loss:2.6874756813049316
# --- round 241 generation ---
# beautiful chinese 5 words poem:愁绎故长致，浮窗妄沆草。厥方为无在，留谷似床台。 loss:2.6932621002197266
# --- round 242 generation ---
# beautiful chinese 5 words poem:园僻汇洞息，话增劳重莺。平老走少远，依屿共黍台。 loss:2.6742191314697266
# --- round 243 generation ---
# beautiful chinese 5 words poem:柳迹甲前夜，别叶鸟落情。半涕奚古土，愿鞭寸赐锋。 loss:2.726311683654785
# --- round 244 generation ---
# beautiful chinese 5 words poem:鸸才存洞外，俗檄合角来。诸蕃仍摩诘，舍日记弗蓉。 loss:2.781672477722168
# --- round 245 generation ---
# beautiful chinese 5 words poem:掣能惟望露，离唱犹泽求。朅弗阒无饮，幽餐趣潮空。 loss:2.7983922958374023
# --- round 246 generation ---
# beautiful chinese 5 words poem:撇友风坡翦，噬云挟掩戒。冰湍款笔议，弱壑拔茅征。 loss:2.7157089710235596
# --- round 247 generation ---
# beautiful chinese 5 words poem:畜露存藓夜，藤乏漠角贤。似歌出安沼，披解细各翰。 loss:2.6804144382476807
# --- round 248 generation ---
# beautiful chinese 5 words poem:妍辉存然崖，平喧莫未同。菊魄骄州财，沙迹岂螺葹。 loss:2.7942087650299072
# --- round 249 generation ---
# beautiful chinese 5 words poem:钦友风消饥，噬讨压苍躬。震绩固养鹭，庭锋肃失车。 loss:2.772078514099121
# --- round 250 generation ---
# beautiful chinese 5 words poem:恧华无缓翦，况诗养者门。岁游二变晓，风日旧令斑。 loss:2.850358009338379
# --- round 251 generation ---
# beautiful chinese 5 words poem:筛床饭子饭，樯维欺蛎窑。派方鳌波共，尺鹤意泽迷。 loss:2.650301694869995
# --- round 252 generation ---
# beautiful chinese 5 words poem:梁生逶蜑音，顶予出半身。涉笔兼骤财，蛮戏读剑眉。 loss:2.7645325660705566
# --- round 253 generation ---
# beautiful chinese 5 words poem:遨击无潮坼，搜云傀儡闲。贞诚虔双遍，佳戏赛剑踱。 loss:2.5785765647888184
# --- round 254 generation ---
# beautiful chinese 5 words poem:荡兴无葱响，噬嗑戒参书。悲搔悬被颅，大里泪足云。 loss:2.8444032669067383
# --- round 255 generation ---
# beautiful chinese 5 words poem:菰已飘前驺，同风别简嗟。迅湍下卷人，知命陨朱幡。 loss:2.9020285606384277
# --- round 256 generation ---
# beautiful chinese 5 words poem:持失出郑蛰，清烹照碊迎。厥哉不改浪，不敌蓑搘魔。 loss:2.9124302864074707
# --- round 257 generation ---
# beautiful chinese 5 words poem:狞题龙吾山雨，持户拂蜜脾。顷纨壑祖引，荆鞭受攒眉 loss:3.2312536239624023
# --- round 258 generation ---
# beautiful chinese 5 words poem:虑王七前人，性乏翰顽空。如橙玩飞堂，王赐角氛眉。 loss:3.1235649585723877
# --- round 259 generation ---
# beautiful chinese 5 words poem:公者薄翼流，风萍负酒角。无橙双泪藉，予词刀轻香。 loss:2.9969704151153564
# --- round 260 generation ---
# beautiful chinese 5 words poem:泗者伽陀具，谭志负林鳞。。微憺矰宠，曷文混真觉。 loss:3.0824031829833984
# --- round 261 generation ---
# beautiful chinese 5 words poem:肉坦无流缝，怀心夜无山。归身惜慰藉，不海散莺云。 loss:3.0619540214538574
# --- round 262 generation ---
# beautiful chinese 5 words poem:域须蘧庐鸣，怀然鼓雨堂。平渡符骤繁，应酒勿伤魔。 loss:2.8782687187194824
# --- round 263 generation ---
# beautiful chinese 5 words poem:溽传须所朗，呼风傀儡还。青人肯比晋，幽御读悲起。 loss:2.795685291290283
# --- round 264 generation ---
# beautiful chinese 5 words poem:腑露达帝叶，捧檄我闽同。所军而蚩舆，犁莽岂回车。 loss:2.7412962913513184
# --- round 265 generation ---
# beautiful chinese 5 words poem:直火无寐，，意色向竹门。官哉烹摩阵，底戏伫勿卖。 loss:2.7089977264404297
# --- round 266 generation ---
# beautiful chinese 5 words poem:岐蔗饭奸溟，蠢蓁煅漠蟷。竭嚣那衣久，青意故义情。 loss:2.6519734859466553
# --- round 267 generation ---
# beautiful chinese 5 words poem:蕊床龙时珠，俭坎尽泽喜。文云俱柏坱，沙列代搘颐。 loss:2.6365599632263184
# --- round 268 generation ---
# beautiful chinese 5 words poem:氄鸸纷杀上，瑞柏但却紫。不稀蚩曲促，凉赐晓引嘉。 loss:2.6892597675323486
# --- round 269 generation ---
# beautiful chinese 5 words poem:赤迹无寐坼，墨仍失一疑。岁生万无外，竟作酒池私。 loss:2.6943037509918213
# --- round 270 generation ---
# beautiful chinese 5 words poem:及世还溟陈，司清傀轻锋。柴去绣双已，把复营颓嘉。 loss:2.5710833072662354
# --- round 271 generation ---
# beautiful chinese 5 words poem:滑蛮出前坼，同窗落潮驰。万逵环双笑，忍客一故亲。 loss:2.657822370529175
# --- round 272 generation ---
# beautiful chinese 5 words poem:斸哳稽架响，萧逸我一汰。潮慎往吾在，向曦殷登春。 loss:2.7761549949645996
# --- round 273 generation ---
# beautiful chinese 5 words poem:葺迹非杠梁，巴云思掩关。稍看烹鬼堂，胜赐看度加。 loss:2.7110884189605713
# --- round 274 generation ---
# beautiful chinese 5 words poem:犬篱切布选，荆蓁欺汉芷。下观犹禹制，大异贮此覆。 loss:2.6378936767578125
# --- round 275 generation ---
# beautiful chinese 5 words poem:楸笙达正佛，蛮者皆积葽。异公鲸波塞，巴讴守攒魔。 loss:2.6257286071777344
# --- round 276 generation ---
# beautiful chinese 5 words poem:穗辉亲弦遰，杯迁翰角跃。晋爵阒无鸟，十餐一渡局。 loss:2.631084442138672
# --- round 277 generation ---
# beautiful chinese 5 words poem:苓失无寐坼，春仍照不洲。不以程蚩上，愿机沧病加。 loss:2.5672903060913086
# --- round 278 generation ---
# beautiful chinese 5 words poem:隘传秉令足，蔗踵煅蛎窑。竭蹶耽来意，意我孰推迁。 loss:2.612764596939087
# --- round 279 generation ---
# beautiful chinese 5 words poem:积绎无缓灵，庭我成一挥。宵识沧少觅，万恬历搘灭。 loss:2.6438469886779785
# --- round 280 generation ---
# beautiful chinese 5 words poem:释床鱼蝘蜓，畬维煅蛎操。翻书养来鸟，况云海草场同 loss:2.635715961456299
# --- round 281 generation ---
# beautiful chinese 5 words poem:瑕色被盐眼，蔬茝愧墨鸣。似醨翔凤种，为蟹蓑桑麻。 loss:2.7249834537506104
# --- round 282 generation ---
# beautiful chinese 5 words poem:沼马七正茹，天苏迟脱梅。迅诚六蓼拜，蔬指趣已心。 loss:2.5586440563201904
# --- round 283 generation ---
# beautiful chinese 5 words poem:娉哳故御芷，寂持杀床移。厥会阒兹桂，际住讯壶门。 loss:2.6992146968841553
# --- round 284 generation ---
# beautiful chinese 5 words poem:朱类出如早，机径压风俱。养人舄寂意，狂飓徒马私。 loss:2.667010545730591
# --- round 285 generation ---
# beautiful chinese 5 words poem:阅萝鸣蝘蜓，崩鱼废自裳。霭店栽为悲，机意却襟裾。 loss:2.6311841011047363
# --- round 286 generation ---
# beautiful chinese 5 words poem:库贮门蝘珠，顾云正反蓉。抚策栽松桂，猿讴窥莛芥。 loss:2.7114202976226807
# --- round 287 generation ---
# beautiful chinese 5 words poem:娓方滋令碧，割炙恣自快。凫鷖无改茑，芳对代代魔。 loss:2.736585855484009
# --- round 288 generation ---
# beautiful chinese 5 words poem:镖登一涯坼，同窗事荑肥。似哉出霜色，赴墟意余中。 loss:2.807553768157959
# --- round 289 generation ---
# beautiful chinese 5 words poem:假鼎猥风鸟，文章世泽冈。朅云敢酒屧，胜觉敢义空。 loss:2.6581807136535645
# --- round 290 generation ---
# beautiful chinese 5 words poem:洫触雾衢骥，荆诗梦青天。圆迕复无调，不话均吟桐。 loss:2.5158591270446777
# --- round 291 generation ---
# beautiful chinese 5 words poem:理迹几蹊梁，海庭草轻间。下逵还五访，更拟机攒衡。 loss:2.611398458480835
# --- round 292 generation ---
# beautiful chinese 5 words poem:浑非风声游，墨曲愧簟贞。春景虽翻共，忍身涤残阳。 loss:2.599470853805542
# --- round 293 generation ---
# beautiful chinese 5 words poem:朝年接岛笑，灯前似夏湃。昔人沧海外，竟唼七经觉。 loss:2.5304572582244873
# --- round 294 generation ---
# beautiful chinese 5 words poem:萁哳故窟道，深树我汝鸣。大堪仍过问，随聚约层魔。 loss:2.578986167907715
# --- round 295 generation ---
# beautiful chinese 5 words poem:冕歌无涯坼，墨舟失玉觉。亭疏疑椠然，人事托征迁。 loss:2.5274457931518555
# --- round 296 generation ---
# beautiful chinese 5 words poem:即叶非宜常，植勿利杙松。岁逵玷使经，按滴寄两车。 loss:2.6626760959625244
# --- round 297 generation ---
# beautiful chinese 5 words poem:筈友汇常床，虚陬竹角芳。西闻劳幽逝，顿湘读耳轻。 loss:2.6369638442993164
# --- round 298 generation ---
# beautiful chinese 5 words poem:涵予谨杠重，衰风正柏嗟。当心宵来访，桃卉翼黄翰。 loss:2.5706887245178223
# --- round 299 generation ---
# beautiful chinese 5 words poem:嵸触惟洞宅，野俗亦防劳。悲哉姜无首，慰鹤佐马招。 loss:2.5820529460906982
# --- round 300 generation ---
# beautiful chinese 5 words poem:注双既正茄，浮陬身汝注。问无疑使钵，貎见欲无如。 loss:2.6866557598114014
# --- round 301 generation ---
# beautiful chinese 5 words poem:诘黄麒麟树，文户寄参夷。万醨惭芗选，发处寂牵裾。 loss:2.7388198375701904
# --- round 302 generation ---
# beautiful chinese 5 words poem:鼪露亦杠梁，庭勿旧图迎。夹置绣壑财，阅壑拔笙征。 loss:2.6317784786224365
# --- round 303 generation ---
# beautiful chinese 5 words poem:骞路风且响，襁餮义一似。坐手沅簟拙，旷冠芦游轻。 loss:2.7649168968200684
# --- round 304 generation ---
# beautiful chinese 5 words poem:忭友分巨暮，怀期劳日夏。养事犹来图，梅餐分黄巡。 loss:2.7084386348724365
# --- round 305 generation ---
# beautiful chinese 5 words poem:燕田亦朝事，残径变塞缟。明出厌芗腥，食单困层樊。 loss:2.6617255210876465
# --- round 306 generation ---
# beautiful chinese 5 words poem:阙马到吾托，顾际事一堂。凫方膏挞独，难滴醉代颐。 loss:2.6746926307678223
# --- round 307 generation ---
# beautiful chinese 5 words poem:货能河难饯，举立兼漠觉。冰戏参疏飞，星惜学相界。 loss:2.8739421367645264
# --- round 308 generation ---
# beautiful chinese 5 words poem:袭题持作崖，摛志力汝苦。岁闻政蚩氓，野汐药笠侣。 loss:2.934401512145996
# --- round 309 generation ---
# beautiful chinese 5 words poem:玩菽秉简妇，匏床煅蛎革。下识符州德，相事棠相筒。 loss:3.0482289791107178
# --- round 310 generation ---
# beautiful chinese 5 words poem:快乡七飘叶，天萍负辟古。与稀柴短阵，犁稍慕剑锋。 loss:2.669543981552124
# --- round 311 generation ---
# beautiful chinese 5 words poem:腊公飘脯茄，所风尺反通。虚闻玷毅夕，难为任相零。 loss:2.8802406787872314
# --- round 312 generation ---
# beautiful chinese 5 words poem:措兴尊末遍，琴颻莫冬芷。下子铅延面，不雁亦公心。 loss:2.702155590057373
# --- round 313 generation ---
# beautiful chinese 5 words poem:拳卜汇洞庭，承忘野者蟷。凫哉能可乘，更簟破犵家。 loss:2.660513401031494
# --- round 314 generation ---
# beautiful chinese 5 words poem:鸂代无风早，沧窗镇未林。将念镇被暑，啖壑尚阑葹。 loss:2.567800998687744
# --- round 315 generation ---
# beautiful chinese 5 words poem:期留缑业寂，深火想院堂。双念翔縠始，雄堪尚可穷。 loss:2.5921976566314697
# --- round 316 generation ---
# beautiful chinese 5 words poem:赬触风潮现，墨潮愧芬聩。巡湍依卷涉，邱莽多可机。 loss:2.6415951251983643
# --- round 317 generation ---
# beautiful chinese 5 words poem:鶒能无声坼，暑冬感不牛。余识低纤在，把然千图香。 loss:2.648789882659912
# --- round 318 generation ---
# beautiful chinese 5 words poem:輵友汇节楫，写于买何涯。岁衣还吟乱，敧意泪清惭。 loss:2.5613038539886475
# --- round 319 generation ---
# beautiful chinese 5 words poem:荻公横人盛，因上慰咨壑。共书虽五夕，应为二摩能。 loss:2.520759344100952
# --- round 320 generation ---
# beautiful chinese 5 words poem:蘩惟写架月，捧檄钟碊避。村江走变法，白惜戬芝长。 loss:2.63946270942688
# --- round 321 generation ---
# beautiful chinese 5 words poem:圳肃齿鸣蜓，战嗑废却生。如移碧霜险，只御好窕香。 loss:2.623629093170166
# --- round 322 generation ---
# beautiful chinese 5 words poem:击玉翻嘘漐，虚子隔水思。岁戏政魂乱，上泻客蔬歧。 loss:2.6814911365509033
# --- round 323 generation ---
# beautiful chinese 5 words poem:鞯友无缓辟，醍漏顾者油。岁岸应谁客，诛客无下火。 loss:2.5134780406951904
# --- round 324 generation ---
# beautiful chinese 5 words poem:斸哳崇迫响，浪檄劳角恩。执蹶耽政宠，茅里意限情。 loss:2.544001340866089
# --- round 325 generation ---
# beautiful chinese 5 words poem:鞮哳幽相事，同从惨所贞。坐来潇洒日，追身沧图啼。 loss:2.5414352416992188
# --- round 326 generation ---
# beautiful chinese 5 words poem:壬肯存节碧，战旌但。地。宵植振蔚支。飞中吾使访， loss:2.6351425647735596
# --- round 327 generation ---
# beautiful chinese 5 words poem:涌饱重古珠，天律忆往赓。南都观蹉短，不远泪足论。 loss:2.647305727005005
# --- round 328 generation ---
# beautiful chinese 5 words poem:丛公达令夜，战秀缴角马。岁闻犹窄港，蔬背分许车。 loss:2.4427356719970703
# --- round 329 generation ---
# beautiful chinese 5 words poem:纯心迎陀具，谭诗剩错疆。将车姜波朗，随土肃韭猱。 loss:2.6538007259368896
# --- round 330 generation ---
# beautiful chinese 5 words poem:蔀方七熳入，迷乐但却林。圆奚六改桂，那偶曦景灭， loss:2.6467344760894775
# --- round 331 generation ---
# beautiful chinese 5 words poem:庇卜随风事，独西入幻知。曷瑟鹭松桂，将蟹寄螺哀。 loss:4.023745536804199
# --- round 332 generation ---
# beautiful chinese 5 words poem:黏雾凤自托，郦湖似汝尘。击然悬拘吼，残宦尊鸥溪。 loss:4.700582981109619
# --- round 333 generation ---
# beautiful chinese 5 words poem:揽舍重如银，去袍駴甘脾。湘策淹古境，欹枭各禅起。 loss:4.7480878829956055
# --- round 334 generation ---
# beautiful chinese 5 words poem:煽勿入一早，巴乔煅相蹄。筑。俱登属，猿指勿容宰。 loss:4.580853462219238
# --- round 335 generation ---
# beautiful chinese 5 words poem:剺沧常逭夏，园目鲍焉饕。牯晴仍摇魂，啖锸伫琐台。 loss:4.051353931427002
# --- round 336 generation ---
# beautiful chinese 5 words poem:苗当浑笼漐，陌讨裸草于。清辉漾壑色，头申讯残春。 loss:3.745427131652832
# --- round 337 generation ---
# beautiful chinese 5 words poem:赵提猥古鬓，畬际独忽悲。苦衣来峥伫，味湘困自暄。 loss:3.613147258758545
# --- round 338 generation ---
# beautiful chinese 5 words poem:洒题鸣翼挈，壶餐枕扬芷。下手漾縠鱼，只讴拔茅锋。 loss:3.4864320755004883
# --- round 339 generation ---
# beautiful chinese 5 words poem:压幡及子茄，司云咏豁鳞。抚冈栽兹桂，犁雾漫乡嘉。 loss:3.310573101043701
# --- round 340 generation ---
# beautiful chinese 5 words poem:匏楚诸蝘狗，俭雄尽错贤。茅言烹溽独，聊楚尤狡狯。 loss:3.2219619750976562
# --- round 341 generation ---
# beautiful chinese 5 words poem:德汉交提斗，横者漫卜，沙济同怅陋，小蟹贮颐刀。竭 loss:3.1070075035095215
# --- round 342 generation ---
# beautiful chinese 5 words poem:蓣传逾参爽，樯谷浑重贤。晋工无无极，相话均斜。。 loss:3.204272508621216
# --- round 343 generation ---
# beautiful chinese 5 words poem:铺玉切吾涉，因来杏儡肥。共方秋海披，尘境盭窒迷。 loss:2.90002703666687
# --- round 344 generation ---
# beautiful chinese 5 words poem:颦霍观肃章，飘俗欲空翻。况领任熊馆，鸥绢剪自蔬。 loss:2.9858298301696777
# --- round 345 generation ---
# beautiful chinese 5 words poem:滨白烂迤烂，厥茝苏一工。妙当涤投鸿，蛮日混相美。 loss:2.880579948425293
# --- round 346 generation ---
# beautiful chinese 5 words poem:旱乡羽藓性，遗颻莫于通。偶醨犹禹拜，稍罢窥篱眉。 loss:2.8224165439605713
# --- round 347 generation ---
# beautiful chinese 5 words poem:亘失绝蹊灵，落襟瘴卜夷。厥子此阶闭，愁巷惟不忉。 loss:2.7834296226501465
# --- round 348 generation ---
# beautiful chinese 5 words poem:驶者对无玩，鸡知作客多。平岸应五继，含源薋菉葹。 loss:3.0796613693237305
# --- round 349 generation ---
# beautiful chinese 5 words poem:魈鹊交衢骥，从延趁社颠。晋酿虔摩疏，余蟹每刀台。 loss:3.2235453128814697
# --- round 350 generation ---
# beautiful chinese 5 words poem:焦菽瓜架德，荆冈伤霭翁。橘鷖栽无啸，欹枭岂真啼。 loss:3.0631368160247803
# --- round 351 generation ---
# beautiful chinese 5 words poem:蕙卜重时豪，因声摧简余。溯仰忍被响，那滴拔狡征。 loss:3.0306127071380615
# --- round 352 generation ---
# beautiful chinese 5 words poem:惭予饭淮回，割茅煅蛎躬。依簪临良赏，促咨莽层嘉。 loss:2.8768091201782227
# --- round 353 generation ---
# beautiful chinese 5 words poem:淰待迎火制，摧者我霭耕。建息能卷涛，忍觉分外空。 loss:2.900773286819458
# --- round 354 generation ---
# beautiful chinese 5 words poem:铎殇惊相偶，交转历澎湃。既觉绣汛纲，毒删莽雾轻。 loss:2.8152658939361572
# --- round 355 generation ---
# beautiful chinese 5 words poem:盛昔对前托，腊类力泽筹。鸥觉振鬼桑，送赐只期卖。 loss:2.7871639728546143
# --- round 356 generation ---
# beautiful chinese 5 words poem:系饮旧一朗，俭冈革簟觉。溯念详溽阵，旷朱万为加。 loss:2.742821455001831
# --- round 357 generation ---
# beautiful chinese 5 words poem:冢待对火密，呼绿讼雷荆。建槛虔无亏，造香欲其葹。 loss:2.793297052383423
# --- round 358 generation ---
# beautiful chinese 5 words poem:较汉莾迢遰，繁乏煅自裳。召稻酬溽壤，小失讯履侣。 loss:2.697511672973633
# --- round 359 generation ---
# beautiful chinese 5 words poem:屴迹达乙选，蛮蓁欺蛎期。竭蹶栽指地，竟义千摇台。 loss:2.7313249111175537
# --- round 360 generation ---
# beautiful chinese 5 words poem:蜀世无时坼，同醐缚乳附。逆纨澄蓼迟，更览看寐面。 loss:2.7108912467956543
# --- round 361 generation ---
# beautiful chinese 5 words poem:陨方涉孤朗，族寥枕积躬。岁识政颜上，文滂看褒间。 loss:2.7442452907562256
# --- round 362 generation ---
# beautiful chinese 5 words poem:亚待复荒徼，伤间静林贤。妙蹶若缥樊，少滴醉浮槎。 loss:2.693890333175659
# --- round 363 generation ---
# beautiful chinese 5 words poem:氄肯存孤崖，平俗隔林堂。不因低无宿，桃卉翼春加。 loss:2.66558837890625
# --- round 364 generation ---
# beautiful chinese 5 words poem:灭农出郑灵，仲冬漠参野。青橙履殊惜，庭讴看可车。 loss:2.6496810913085938
# --- round 365 generation ---
# beautiful chinese 5 words poem:蝶传无里夕，残西来漈夕。飓魅无无限，妙引木心同。 loss:2.706726551055908
# --- round 366 generation ---
# beautiful chinese 5 words poem:拉霍雄放远，手摘垂浪吾。茅忆完存桂，幽蟹勿螺颐。 loss:2.7068567276000977
# --- round 367 generation ---
# beautiful chinese 5 words poem:今石剧氏阴，俊聒蔬伊塞。逆掠完无亏，平乃只强女。 loss:2.5996782779693604
# --- round 368 generation ---
# beautiful chinese 5 words poem:房击当南，独露移色路迷。幽编奚赐乱，宦戏只睡踱。 loss:2.753937244415283
# --- round 369 generation ---
# beautiful chinese 5 words poem:稍雾逾架嫩，匏愆瘴蛎跃。颷酿酬可亏，造乃阻清招。 loss:2.6308820247650146
# --- round 370 generation ---
# beautiful chinese 5 words poem:脏鹊鸣君狗，俭云期儡能。步漾承溽暑，稍锸偈生辉。 loss:2.6040334701538086
# --- round 371 generation ---
# beautiful chinese 5 words poem:有晓凌乡远，啼情毗舍耶。顷店无尝闭，入意为束陶。 loss:2.620690107345581
# --- round 372 generation ---
# beautiful chinese 5 words poem:藏绿尊啸月，瑞檄力参宽。逆掠酬无里，妙滞旧堪卓。 loss:2.524294376373291
# --- round 373 generation ---
# beautiful chinese 5 words poem:轺失无涯坼，暑染逐泽身。清游程芗坐，难偶述头关。 loss:2.5300023555755615
# --- round 374 generation ---
# beautiful chinese 5 words poem:岛中上看妙，潮言迹有挥。凫游鞭骤乱，嬉戏刀剑锋。 loss:2.576371431350708
# --- round 375 generation ---
# beautiful chinese 5 words poem:堪白逢逭鸥，留我攒阴鱼。不逵低摇豫，啖指意花倾。 loss:2.688066005706787
# --- round 376 generation ---
# beautiful chinese 5 words poem:麒者加盛入，割炙恣听俦。平识符鬼澎，把迹芦狡嘉。 loss:2.72363018989563
# --- round 377 generation ---
# beautiful chinese 5 words poem:寒雨浮渡远，绝忘君碊林。所园悬谁朗，上雁一囹圄。 loss:2.666171073913574
# --- round 378 generation ---
# beautiful chinese 5 words poem:绊公飘三露，同云事反三。贞诚虔拜疏，汲壑尚摇厅。 loss:2.6173946857452393
# --- round 379 generation ---
# beautiful chinese 5 words poem:掀玉切嘘嫩，喧诗渡兰嗟。如游蚩蚩氓，涩锋读亦忉。 loss:2.539304256439209
# --- round 380 generation ---
# beautiful chinese 5 words poem:赊楚猥自珠，腊鼠累自谋，造少得熊临。万筵销垂齿， loss:2.5528056621551514
# --- round 381 generation ---
# beautiful chinese 5 words poem:擎迹惊灶李，司云蜃秀靡。异语鲸波伏，难多开襟概。 loss:2.6960902214050293
# --- round 382 generation ---
# beautiful chinese 5 words poem:切民七荆月，寒光袭乐妙。如岂双幽地，竟滂殷缠吟。 loss:2.6792731285095215
# --- round 383 generation ---
# beautiful chinese 5 words poem:要幡及作崖，平茝均马苦。雄盆铅椠凄遍。忍子来尝足 loss:2.567272901535034
# --- round 384 generation ---
# beautiful chinese 5 words poem:祉触飞鸟取，兰云远其情。凄以衔双屧，送客展梁书。 loss:2.527998685836792
# --- round 385 generation ---
# beautiful chinese 5 words poem:植和逾火饭，俭湖我大贤。麦鷖依桃乘，林敌寄浮空。 loss:2.6476056575775146
# --- round 386 generation ---
# beautiful chinese 5 words poem:衢方复深托，仲云静未改。所识貌径阁，把罢勿余槎。 loss:2.5439882278442383
# --- round 387 generation ---
# beautiful chinese 5 words poem:溯生瓜盛入，割逸到如身。引领聊无涉，平境又西驰。 loss:2.565265417098999
# --- round 388 generation ---
# beautiful chinese 5 words poem:丹黎理觞庭，摧田身自快。岁名犹拉咽，园见静如明。 loss:2.5771920680999756
# --- round 389 generation ---
# beautiful chinese 5 words poem:谡马飘乙曲，油负裸墨鸿。策弄完川阁，犁剑窥寸眉。 loss:2.5408685207366943
# --- round 390 generation ---
# beautiful chinese 5 words poem:谩莽翻功狗，樯床煅蛎窑。柴书听禹吼，大来涤亦郡， loss:2.5760891437530518
# --- round 391 generation ---
# beautiful chinese 5 words poem:萋苗高南愿，巴云话秀嗟。坐识还过窕，折觉涤荫翁。 loss:2.5266757011413574
# --- round 392 generation ---
# beautiful chinese 5 words poem:苹风逢渡偕，勤人傀弄拙。抚午阒蓼桂，思队着海中情 loss:2.5586352348327637
# --- round 393 generation ---
# beautiful chinese 5 words poem:下海问谁沓，兰纶杀蜴堂。往游环少赏，烂戏那散菜。 loss:2.5855937004089355
# --- round 394 generation ---
# beautiful chinese 5 words poem:凭岁贪迤市，前枝檐阴。。天天一差轨，月惜盭窒赓。 loss:2.7068207263946533
# --- round 395 generation ---
# beautiful chinese 5 words poem:朅存幽能朗朝。如敢情其素。耽看绣令鸟，年有卑令美 loss:2.651369094848633
# --- round 396 generation ---
# beautiful chinese 5 words poem:蓓友传洞矜，遗然渡水人。置魄藤汛扫，阅湘旧雾通。 loss:2.730215311050415
# --- round 397 generation ---
# beautiful chinese 5 words poem:禳虫猥肯取，遥空迟草靡。北问无喜章，烦节耳菉葹。 loss:2.5612010955810547
# --- round 398 generation ---
# beautiful chinese 5 words poem:贵客虚厨具，谭枝莫殊错。光园为漫险，愁敌落已趣。 loss:2.7773892879486084
# --- round 399 generation ---
# beautiful chinese 5 words poem:噩迹痕田盛，争时野草贤。召哉推政诘，四住轸怅尘。 loss:4.163969993591309
# --- round 400 generation ---
# beautiful chinese 5 words poem:绊触无寐坼，怀龙压星苔。湘手验啸教，问汐轸螺谙。 loss:4.230159282684326
# --- round 401 generation ---
# beautiful chinese 5 words poem:窄月蛮迤宅，谭贪竹往苦。要哉不舂撞，涩名鸟钓荧。 loss:3.8594188690185547
# --- round 402 generation ---
# beautiful chinese 5 words poem:涯时频沧高，姑子宜墨屿。要方鳌岫响，拘藉诉浮神。 loss:3.869720220565796
# --- round 403 generation ---
# beautiful chinese 5 words poem:蛱萝幽臾挈，樯蓁愧蔚窑。悲簇罗镜息，猿稍赛生菜。 loss:3.687818765640259
# --- round 404 generation ---
# beautiful chinese 5 words poem:娱玉无郑坼，怀熟忽栩瀣。兼质六蓼海，宾州尚通。啼 loss:3.321622371673584
# --- round 405 generation ---
# beautiful chinese 5 words poem:授檐饭浮原，冰岁癸马蓬。飘人禅异警，鸥单岂赐樊。 loss:3.339872121810913
# --- round 406 generation ---
# beautiful chinese 5 words poem:羞公凄嘘漐，同袭均贩芷。大锸为宴陋，紫形无何辈。 loss:3.2312564849853516
# --- round 407 generation ---
# beautiful chinese 5 words poem:侯传鹅灶时，藤萝煅漠耕。平妨漾幽赏，更巘本拙心。 loss:3.0734634399414062
# --- round 408 generation ---
# beautiful chinese 5 words poem:店楚尚提挈，匏床亦汉翁。糟哉幽须伫，啖节结景魔。 loss:3.083621025085449
# --- round 409 generation ---
# beautiful chinese 5 words poem:麦床龙稽妇，安衢檐蛈屿云宵香趣澎鞍。养店仙须拙， loss:3.1291096210479736
# --- round 410 generation ---
# beautiful chinese 5 words poem:瞰业痕田茝，看苏均卜只。柴方那松久，灌蠢诉虞粝。 loss:3.100116491317749
# --- round 411 generation ---
# beautiful chinese 5 words poem:燠予无涯夕，噬章兴一饶。不来翔酒在，向幅看上毛。 loss:3.047804832458496
# --- round 412 generation ---
# beautiful chinese 5 words poem:莼哳逃廌立，浮观身转贫。坐盆销魂我，西冥痕繁侣。 loss:3.0453085899353027
# --- round 413 generation ---
# beautiful chinese 5 words poem:窟农既以夜，踵柏欺角躬。誓道耽息地，淜榔尤羽狯。 loss:2.9160447120666504
# --- round 414 generation ---
# beautiful chinese 5 words poem:礽殇雄湖注，南观亦乐疆。朅公芦夏地，明命二三天。 loss:2.862619400024414
# --- round 415 generation ---
# beautiful chinese 5 words poem:澈尔逾令茹，匏然仗草肥，咄福兼至诚，榴源守层池。 loss:2.8838205337524414
# --- round 416 generation ---
# beautiful chinese 5 words poem:乃客涉难外，火炙已行之。不怜针蚩氓，毒背只赐樊。 loss:2.6834659576416016
# --- round 417 generation ---
# beautiful chinese 5 words poem:黮虹存奸期，浑户顾往榷。半光仍曲逝，触咨细春池。 loss:2.8099637031555176
# --- round 418 generation ---
# beautiful chinese 5 words poem:骄勿亦蹊竹，终复世所停。震爵旧可意，甘作涤残春。 loss:2.6759207248687744
# --- round 419 generation ---
# beautiful chinese 5 words poem:奇往牛藓回，植然霭繁牙。坐槎蚩菊飞，风草履推对。 loss:2.6881799697875977
# --- round 420 generation ---
# beautiful chinese 5 words poem:闼传逾及回，畬树寄自芷。鞭鷖鹭啸拙，为梦魂犵狫。 loss:2.6582529544830322
# --- round 421 generation ---
# beautiful chinese 5 words poem:蠎绎鸣衢屿，承乏漠漠予。将才姜岫议，犁锸应绵藏。 loss:2.7255144119262695
# --- round 422 generation ---
# beautiful chinese 5 words poem:巅能估弦夜，清袭桑笼疆。频午能改涉，犁锸岂弥嘉。 loss:2.685803174972534
# --- round 423 generation ---
# beautiful chinese 5 words poem:絙触蘧洞蜓，油子野自饶。布息鹭啸地，追怀涤短绘。 loss:2.7114462852478027
# --- round 424 generation ---
# beautiful chinese 5 words poem:稿卜交衢妇，支蓁事贱避。愿言为海外，置身对仞踪。 loss:2.654949903488159
# --- round 425 generation ---
# beautiful chinese 5 words poem:融篱无渡坼，心窗落漈长。寥笔观变然，敧序尤素觉。 loss:2.6339783668518066
# --- round 426 generation ---
# beautiful chinese 5 words poem:构歌逾令茹，神诗仗漠嗟。远稀悬陋朗，犁背粉剑卖。 loss:2.7334229946136475
# --- round 427 generation ---
# beautiful chinese 5 words poem:泻床无寐重，重漏杀云愁。米鷖能阶籴，幽蟹野螺心。 loss:2.7032761573791504
# --- round 428 generation ---
# beautiful chinese 5 words poem:莺秋加看冠，族类复不望依。虚蕃仍笔息，旷锋读影轻 loss:2.59356427192688
# --- round 429 generation ---
# beautiful chinese 5 words poem:杉提寄右累，游间浑上快。逆忆聊桃入，荆食料繁机。 loss:2.7026402950286865
# --- round 430 generation ---
# beautiful chinese 5 words poem:亍触凤湖屿，野者露浪传。妙性详戟响，陈政萧篱锋。 loss:2.5758330821990967
# --- round 431 generation ---
# beautiful chinese 5 words poem:介公鹅儿嫩，壶苇莫翘跃。誓手步啸地，淜滂殷相晏。 loss:2.614283561706543
# --- round 432 generation ---
# beautiful chinese 5 words poem:舰友飞长笛，去知赴磥间。狂禽详壑色，西冥蚩桑独， loss:2.748267412185669
# --- round 433 generation ---
# beautiful chinese 5 words poem:涵题既布私，野枝柏雷林。虑囚参双选，沙学讯床侣。 loss:2.604006767272949
# --- round 434 generation ---
# beautiful chinese 5 words poem:暘予秉灶性，诛愆欺霭芷。下识鲸颜尽，余命约层侣。 loss:2.683147668838501
# --- round 435 generation ---
# beautiful chinese 5 words poem:瓴哳河藓看，水袭合笼龙。顷方鳌命议，万馔野禁，天 loss:2.532927989959717
# --- round 436 generation ---
# beautiful chinese 5 words poem:倩贮无缓稽，非阁趁氓盟。晋槛听无远，辗吹对床零。 loss:2.5475616455078125
# --- round 437 generation ---
# beautiful chinese 5 words poem:敦提煎稽摧，樯雄欺兰芷。竭蹶栽息历，蛮讴分市卖。 loss:2.6847708225250244
# --- round 438 generation ---
# beautiful chinese 5 words poem:蒙题甲及茹，蛮岐散重贤。佛书画缥缈，送见欲禁届。 loss:2.6286041736602783
# --- round 439 generation ---
# beautiful chinese 5 words poem:只拙营蛸是，终子旧施鱼。迅质步蓼然，无郭铁沧晖。 loss:2.5781188011169434
# --- round 440 generation ---
# beautiful chinese 5 words poem:郁玉女令涉，余籍均纪间。图午升縠响，淡持能羽迁。 loss:2.671712636947632
# --- round 441 generation ---
# beautiful chinese 5 words poem:髻菽牛脯梦，从途逸鹿林。虑堪须窈尽，楚直吟阳鼓。 loss:2.6652939319610596
# --- round 442 generation ---
# beautiful chinese 5 words poem:赊歌迎作夜，裁云梦情寻。不语观宿懒，予住薋菉葹。 loss:2.607027053833008
# --- round 443 generation ---
# beautiful chinese 5 words poem:箨白估笼涉，细衢均庭颠。征手聊川吼，幽聚勿莛迁。 loss:2.6371841430664062
# --- round 444 generation ---
# ...
# --- round 854 generation ---
# beautiful chinese 5 words poem:硬息崇正回，双旌割现。。桶零忽古朗。见言故谁恸， loss:3.1781084537506104
# --- round 855 generation ---
# beautiful chinese 5 words poem:歉沙切弦息，清庭摘翠颠。正术还须辟，问意博梁美。 loss:3.0623559951782227
# --- round 856 generation ---
# beautiful chinese 5 words poem:科岭非南国，飘际却不挥。飘花州十尽，赋幅尤狡狯。 loss:2.9284863471984863
# --- round 857 generation ---
# beautiful chinese 5 words poem:床和亦蹊暑，鱼味羱学嘬。泉车漾幽德，残近对素关。 loss:2.7537779808044434
# --- round 858 generation ---
# beautiful chinese 5 words poem:见日处年雪，心星落漈肥。岛理销幽伏，促戏刀力趣。 loss:2.794797420501709
# --- round 859 generation ---
# beautiful chinese 5 words poem:桡辉饭淮冥，杯随癸不松。谁衣藤履乱，问惜偈相关。 loss:2.8187294006347656
# --- round 860 generation ---
# beautiful chinese 5 words poem:牒卜随绿久，饕湖困命诚。震哉阒卷桂，门汐剪螺刀。 loss:2.7592453956604004
# --- round 861 generation ---
# beautiful chinese 5 words poem:赴不无成涉，同说苦马迎。暂店耽衣桂惜。坐逢政柏氓 loss:2.682551622390747
# --- round 862 generation ---
# beautiful chinese 5 words poem:应生千胝道，余甲落鹿。。人辉盘所昧，更梦静里穷。 loss:2.6615517139434814
# --- round 863 generation ---
# beautiful chinese 5 words poem:崩和鹅脯茄，争雄剩水陈。米归沧无侍，毋餐各空冰。 loss:2.5520923137664795
# --- round 864 generation ---
# beautiful chinese 5 words poem:盎存尚以珠，神者等云牯。米晴画鼍教，哀章野秋遥。 loss:2.588923931121826
# --- round 865 generation ---
# beautiful chinese 5 words poem:体传难蹊教，喧风杏自凉。宦午闻无调，烦源不用音。 loss:2.547297477722168
# --- round 866 generation ---
# beautiful chinese 5 words poem:煅公无卑性，暑蕙渡一邱。岁浪无泓外，谁与不所边。 loss:2.6295974254608154
# --- round 867 generation ---
# beautiful chinese 5 words poem:甘苗含鹿灶，喧枝乃贱迎。松语无际兰，不意透茑疏。 loss:2.6564760208129883
# --- round 868 generation ---
# beautiful chinese 5 words poem:崿黄莫乙顷，庭目几防洒。涉笔偶须海，宾客径步生。 loss:2.6100857257843018
# --- round 869 generation ---
# beautiful chinese 5 words poem:牛者逶弦回，鱼然寄牛肥。岁容鲸皇德，残为增郫招。 loss:2.554658889770508
# --- round 870 generation ---
# beautiful chinese 5 words poem:今拓岂郦胸，徒麻知萦堂。餐疏藤陀偈，稍世莽生废。 loss:2.620889663696289
# --- round 871 generation ---
# beautiful chinese 5 words poem:逶农愿吾茹，通予翰蛈蟷。平识倭纤域，曷鷖印可。冰 loss:2.5651066303253174
# --- round 872 generation ---
# beautiful chinese 5 words poem:颗方令通偈，争复讼素还。因盆姜縠纹，元词窥篱樊。 loss:2.5611302852630615
# --- round 873 generation ---
# beautiful chinese 5 words poem:年日交江外，神绎每林空。何簪漾履繁，问异蛮雾鞍。 loss:2.5522139072418213
# --- round 874 generation ---
# beautiful chinese 5 words poem:濠卜简洞，流亲。愁舟乃素人。公蕃无虫刀，涩滑本中 loss:2.443694591522217
# --- round 875 generation ---
# beautiful chinese 5 words poem:岔哳心安宁，交深惨澹书。将念岁步赏，湘日鞭论条。 loss:2.539355993270874
# --- round 876 generation ---
# beautiful chinese 5 words poem:阜方迎架漐，油絙渡水堂。旅领兼飘上，沙客酒回生。 loss:2.483205556869507
# --- round 877 generation ---
# beautiful chinese 5 words poem:埴碧逶蜑群，狂踵煅蛎苦。偶哉久羽沼，稍熳翼闻轻。 loss:2.6495704650878906
# --- round 878 generation ---
# beautiful chinese 5 words poem:弭惟无缓翦，饕去攒沅皇。昭纨澄卷啸，含谬尔许香。 loss:2.478854179382324
# --- round 879 generation ---
# beautiful chinese 5 words poem:汝方复窟漐，油田戒瞻杭。麦蹶鹭峨宠，庭人本弗陶。 loss:2.5487873554229736
# --- round 880 generation ---
# beautiful chinese 5 words poem:焱衍逾养时，割萝坞同曲。半疏旧然法，佳客共林空。 loss:2.542861223220825
# --- round 881 generation ---
# beautiful chinese 5 words poem:蠖触雄觞骥，天熟溅强，支勿还须久，凉音学鸡零。岁 loss:2.441666603088379
# --- round 882 generation ---
# beautiful chinese 5 words poem:住檐无从缝，胡玄戒簟暮。西头政蚩法，本白引相肃。 loss:2.385826826095581
# --- round 883 generation ---
# beautiful chinese 5 words poem:吓徒迎田斗，同足桑可堂。麦工不凤昧，凉意矢萧条。 loss:2.4605765342712402
# --- round 884 generation ---
# beautiful chinese 5 words poem:撞歌及脯茄，争火仗杙贤。宦稻那头诚，沙见似足关。 loss:2.535064697265625
# --- round 885 generation ---
# beautiful chinese 5 words poem:樯菽亦秋赖，无本照转蓬。坐都眺无意，慰放剑酒招。 loss:2.4452621936798096
# --- round 886 generation ---
# beautiful chinese 5 words poem:嫁萝尚田侄，不空檐鼠间。正规升已在，园复息相关。 loss:2.4852819442749023
# --- round 887 generation ---
# beautiful chinese 5 words poem:篑沧逶翼音，相聒均飘大。功须无潮纪，应滑榜斜颐。 loss:2.4332661628723145
# --- round 888 generation ---
# beautiful chinese 5 words poem:嶔哳复性难，浪忘酒已经。朅衣无处纪，欹枭鸣如烟。 loss:2.5387063026428223
# --- round 889 generation ---
# beautiful chinese 5 words poem:竖鹤无前言，沧窗落事峦。所事谢幼舆，毒迹莽琐鞍。 loss:2.452484369277954
# --- round 890 generation ---
# beautiful chinese 5 words poem:湱宗东梦稽，醍说病蜜。飞稀眺笔息，我发夏爵市。寸 loss:2.479119300842285
# --- round 891 generation ---
# beautiful chinese 5 words poem:谀甘沙衢籁，天苇丝脱械。海园持慰少，深吹备桑春。 loss:2.420884847640991
# --- round 892 generation ---
# beautiful chinese 5 words poem:蕤俗旧令喜，报雄废蛎鸣。大香聊五屧，触勿书时空。 loss:2.4985432624816895
# --- round 893 generation ---
# beautiful chinese 5 words poem:雉歌贪陀四，藤乏适命间。四须悬毅朗，终际意其愁。 loss:2.4611902236938477
# --- round 894 generation ---
# beautiful chinese 5 words poem:阔瘴潜迟鹿，厥焉崇蔚鸿。搘愁翔波调，顿寸无度加。 loss:2.4030134677886963
# --- round 895 generation ---
# beautiful chinese 5 words poem:颻履饭节术，殊云鸡掩嗟。昭质完夏遍，入引蓑园私。 loss:2.4770257472991943
# --- round 896 generation ---
# beautiful chinese 5 words poem:帽友分自豪，达生光尘寻。羡菊无锦足，将览轸螺真。 loss:2.4019055366516113
# --- round 897 generation ---
# beautiful chinese 5 words poem:聘鸸简廌立，百籍趁尘苔。大生倭为鸟，折厚对海池。 loss:2.569495439529419
# --- round 898 generation ---
# beautiful chinese 5 words poem:恨叶估三许，族类出里卑。手言还鸡面，送客溷束嘉。 loss:2.487271547317505
# --- round 899 generation ---
# beautiful chinese 5 words poem:礽友随君彼，鱼枝羱乳嗟。积盆无会会，坐恬病万寺。 loss:2.4871773719787598
# --- round 900 generation ---
# beautiful chinese 5 words poem:蒜哳无行鸟，尚亲伏施附。昭纨雪夏簟，匏引尚度絓。 loss:2.5461935997009277
# --- round 901 generation ---
# beautiful chinese 5 words poem:岫岭蘧能避，俭床矜大璞。余寒无海外，孤与共漫临。 loss:2.620234727859497
# --- round 902 generation ---
# beautiful chinese 5 words poem:远日渺年欢，妙际却相招。曷晴仙缥缈，缘麻寸存居。 loss:2.4389593601226807
# --- round 903 generation ---
# beautiful chinese 5 words poem:连歌苔廌思，雪树积贞姿。贞质完无亏，造政宅浮蛮。 loss:2.496485710144043
# --- round 904 generation ---
# beautiful chinese 5 words poem:殿源秉作至，崩伤革重渡。亭午详笔议，毒物混琐耳。 loss:2.436340093612671
# --- round 905 generation ---
# beautiful chinese 5 words poem:头楼风水味，潮与迹并阑。建影鸿豚鼓，曷莽薋鸡鼓。 loss:2.458109140396118
# --- round 906 generation ---
# beautiful chinese 5 words poem:萎提当右挈，裁翼煅百蟷。偶言须使屧，忍纡只时名。 loss:2.492457389831543
# --- round 907 generation ---
# beautiful chinese 5 words poem:僧叶逶牛遍，今籍均墨鸣。仙零姜镜颅，稍蠢只真车。 loss:2.393462657928467
# --- round 908 generation ---
# beautiful chinese 5 words poem:置失逾正茹，蔗茅煅蛎舟。虑策那一偶，暑枭伤已洲。 loss:2.507551670074463
# --- round 909 generation ---
# beautiful chinese 5 words poem:坐中上茫伫，蔬慽力翘。。开军一安意，留唼落住藏。 loss:2.4223570823669434
# --- round 910 generation ---
# beautiful chinese 5 words poem:欤龙君无事，喜唱棹簟芳。三门玷无客，心画中住藏。 loss:2.4527275562286377
# --- round 911 generation ---
# beautiful chinese 5 words poem:鄂黄无成坼，愿者攒命附。宅盆不深会，相及筹斜。昭 loss:2.488690137863159
# --- round 912 generation ---
# beautiful chinese 5 words poem:抿萝交涉骥，旋诗敢物穷。三规漾菊赏，犁锸应时加。 loss:2.3466458320617676
# --- round 913 generation ---
# beautiful chinese 5 words poem:凈衍无寐翦，残漏苦吟幽。驱策参末议，弱稍拔剑征。 loss:2.469386100769043
# --- round 914 generation ---
# beautiful chinese 5 words poem:磕友随坡籁，搜讨穷慨学。清崦媚说雨，文镳漫短春。 loss:2.4704055786132812
# --- round 915 generation ---
# beautiful chinese 5 words poem:淰辉莫吾夜，畬方别风汰。不香蚩蚩舆，毒迹趣忘洲。 loss:2.409857749938965
# --- round 916 generation ---
# beautiful chinese 5 words poem:脑衍无郑翦，后杯趁攀附。既会推曲姜，巴客转露卑。 loss:2.4408516883850098
# --- round 917 generation ---
# beautiful chinese 5 words poem:赴农复民庚，腊际还大饶。平识万谁辈，听处为无句。 loss:2.518357276916504
# --- round 918 generation ---
# beautiful chinese 5 words poem:宇业逾作崖，俭用莫松林。无妨政幽共，促指颷马招。 loss:2.461440324783325
# --- round 919 generation ---
# beautiful chinese 5 words poem:箱方迎通落，含子钟伊愕。乃中一浅在，头似禾图绘。 loss:2.353018283843994
# --- round 920 generation ---
# beautiful chinese 5 words poem:奈雾莾凉争，裁发野渐改。糟醨旧已啜，民笑棠郫筒。 loss:2.4967072010040283
# --- round 921 generation ---
# beautiful chinese 5 words poem:取公风书早，胡去事溪归。残当一处净，百我对芬忧。 loss:2.5544302463531494
# --- round 922 generation ---
# beautiful chinese 5 words poem:肠，寐化续，我时植其关。怀醐蚩椠赏，食列尔市卖。 loss:2.3873705863952637
# --- round 923 generation ---
# beautiful chinese 5 words poem:妥萝猥能事，松声我碊长。醍然走指楚，入以无清趣。 loss:2.4516050815582275
# --- round 924 generation ---
# beautiful chinese 5 words poem:押黄无方下，同漏侍雨垂。岁三犹纤酒，又写着琐颐。 loss:2.4718947410583496
# --- round 925 generation ---
# beautiful chinese 5 words poem:芥凤无葱远，草我钟碊翁。执蹶栽学色，淡域鸟相亲。 loss:2.4250710010528564
# --- round 926 generation ---
# beautiful chinese 5 words poem:验幡秉笼时，发乐草重诗。佛午阒添遍，悠逐任碎目。 loss:2.4562511444091797
# --- round 927 generation ---
# beautiful chinese 5 words poem:蝎公瓜孤崖。梅岐枕所躬。不簪眺履色，文似尽羽零。 loss:2.500706672668457
# --- round 928 generation ---
# beautiful chinese 5 words poem:阚方伽陀选，支迁暗霭豹。正术面可忆，尺口守万菜。 loss:2.3534677028656006
# --- round 929 generation ---
# beautiful chinese 5 words poem:卌息无前穆，暑云梦垂好。真中肯绘星。存置曦赐嘉。 loss:2.472154140472412
# --- round 930 generation ---
# beautiful chinese 5 words poem:草阙莺衢短，琴迁欺角恩车当忽学怅卜，啖已看回罫。 loss:2.327690601348877
# --- round 931 generation ---
# beautiful chinese 5 words poem:渡过潜氏岩，不寒访子同。片盆漾步颅，顿节莽菔芥。 loss:2.4192583560943604
# --- round 932 generation ---
# beautiful chinese 5 words poem:捷者良弦笑，青苇溅纪香。如端羲皇坐，忍为意昧。离 loss:2.369812488555908
# --- round 933 generation ---
# beautiful chinese 5 words poem:樵簟既回佛，户床矜重璞。执鷖固承教，粗冠料琐葹。 loss:2.4267420768737793
# --- round 934 generation ---
# beautiful chinese 5 words poem:佐才逾节佛，报田野汝獾。官言须过息，折寸物音悲。 loss:2.369837760925293
# --- round 935 generation ---
# beautiful chinese 5 words poem:蚕魂翻鹿狗，樯餐裸蛎窑。偶嚣那巡祷，把锸漫层。。 loss:2.570013999938965
# --- round 936 generation ---
# beautiful chinese 5 words poem:半快迢提果，普寐莫翘跃。耽言步承宠，哀滑印菔卖。 loss:2.5305917263031006
# --- round 937 generation ---
# beautiful chinese 5 words poem:柩鸸无缓翦，搜餮幸餐书公。当须连吾选，缘濯尚篱乘 loss:2.3958749771118164
# --- round 938 generation ---
# beautiful chinese 5 words poem:屯拙冥帝德，飘火寄重翁。槎归依异警，谓源岂阳朔。 loss:2.3648874759674072
# --- round 939 generation ---
# beautiful chinese 5 words poem:糁哳惟阳寂，雪语隔院夷。明崦帘翠觉，沅纡鸣清念。 loss:2.596609592437744
# --- round 940 generation ---
# beautiful chinese 5 words poem:莿苗无意细，移径压碧移。米工无计足，鸥历息齿通。 loss:2.788961410522461
# --- round 941 generation ---
# beautiful chinese 5 words poem:奇客缑垂国，海涯袭熟翁，风是环尤早，沙拟讯壶粝。 loss:2.980891227722168
# --- round 942 generation ---
# beautiful chinese 5 words poem:律蔗屯饧灶，茅枝煅蛎窑。乘念那末着，弱锸岂有生。 loss:2.6504735946655273
# --- round 943 generation ---
# beautiful chinese 5 words poem:清雨重寿胜，春苏田久舟。舍性淹头法，含酸殷生思。 loss:2.4976768493652344
# --- round 944 generation ---
# beautiful chinese 5 words poem:昕能蘧多图，同觉普构鼓。顷店不川足，其梦正子同。 loss:2.5399153232574463
# --- round 945 generation ---
# beautiful chinese 5 words poem:骠黄无村缝，非漏一其高。乘凋聊古忆，榴方漫盘名。 loss:2.3969857692718506
# --- round 946 generation ---
# beautiful chinese 5 words poem:频拙纷帝适，归露洛社芷。偶弄戏及息，草为属阑删。 loss:2.4899845123291016
# --- round 947 generation ---
# beautiful chinese 5 words poem:檀黄无前雨，海去四木角。不际环说烂，毒熳刀海毒堆 loss:2.452378034591675
# --- round 948 generation ---
# beautiful chinese 5 words poem:镰方无要响，松柏落凡注。餐哉双念泓，思有许如怍。 loss:2.702425956726074
# --- round 949 generation ---
# beautiful chinese 5 words poem:遭豁愿吾佛，蔗类煅蛎鸿。柴影无空限，辗拟围孔嘉。 loss:2.6661221981048584
# --- round 950 generation ---
# beautiful chinese 5 words poem:蓉色鞭零人，瑞檄钟伊鱼。雄别二镜念，守锸赛琐嘉。 loss:2.4518206119537354
# --- round 951 generation ---
# beautiful chinese 5 words poem:猛公当杠愿，鸥田无草今。自逵断共共，随赐野微轻。 loss:2.341390609741211
# --- round 952 generation ---
# beautiful chinese 5 words poem:雷汉风溟坼，篱与叶忽昧。凄人摧说句，风宦慰清所。 loss:2.6155524253845215
# --- round 953 generation ---
# beautiful chinese 5 words poem:徽展分衢鼓，神枝事一堂。更以羲酒共，清馔孰者溟。 loss:2.5757291316986084
# --- round 954 generation ---
# beautiful chinese 5 words poem:贵业蓣作崖，俭鼠裸霭间。遥闻低窄港，桥背受已卖。 loss:2.5144989490509033
# --- round 955 generation ---
# beautiful chinese 5 words poem:别遥尊卜虫，兰类裸簟斜。小头悬学在，清飓白望束。 loss:2.565829277038574
# --- round 956 generation ---
# beautiful chinese 5 words poem:绀鸸雄延寂，浪聒非伊夷。藏氏虔笔阵，问冠放可悲。 loss:2.5274510383605957
# --- round 957 generation ---
# beautiful chinese 5 words poem:逝棚常通密，鱼餐羱蜴贤。竭手步无夏，鸱枭翼忘悔。 loss:2.5678207874298096
# --- round 958 generation ---
# beautiful chinese 5 words poem:荜霍虫痕短，徒诗旧何谓。死深犹室警，鸥坐应闻楼。 loss:2.5569300651550293
# --- round 959 generation ---
# beautiful chinese 5 words poem:稗待迎火密，呼复拟孤阳。夹工阒啸客，相响靛阑零， loss:2.474787473678589
# --- round 960 generation ---
# beautiful chinese 5 words poem:公歌交臾骥，天年战其关。半逵而尊泻，宦头伫菔碎。 loss:2.4186599254608154
# --- round 961 generation ---
# beautiful chinese 5 words poem:扈频理长露，松予累浮谋。告方鞭挞壤，本头牛素绘。 loss:2.40374755859375
# --- round 962 generation ---
# beautiful chinese 5 words poem:匝篱无流思，谁径能角求。谓槎无无夏，应物只斜思。 loss:2.462275981903076
# --- round 963 generation ---
# beautiful chinese 5 words poem:诉传谨蛸夜，若情增纪寂。稍戏步蓼阳，敢岂任尘轻。 loss:2.3622708320617676
# --- round 964 generation ---
# beautiful chinese 5 words poem:絇友理觞农，旋蓁煅角素。人移念皇，，宾落有微荧。 loss:2.3824384212493896
# --- round 965 generation ---
# beautiful chinese 5 words poem:形汉持帝农，喧枝桑殊椓。平门低窄港，晴熳髫存葹。 loss:2.3458995819091797
# --- round 966 generation ---
# beautiful chinese 5 words poem:秘令兰郦斗，清法亦对悲。画辈观兹化，忍滴尤清菜。 loss:2.534884452819824
# --- round 967 generation ---
# beautiful chinese 5 words poem:坚幡秉沙足，流枝旧一马。岁坞藤幽外，待序看面着。 loss:2.446094036102295
# --- round 968 generation ---
# beautiful chinese 5 words poem:绸和飘凉茹，野苏卖往蟷。晋爵壤汛拙，重暗语遥之。 loss:2.355469226837158
# --- round 969 generation ---
# beautiful chinese 5 words poem:或农蘧冥是，承乏适霭御。糟诗玉来鸟，荃仿在春举。 loss:2.333805799484253
# --- round 970 generation ---
# beautiful chinese 5 words poem:泗鹿莫臾常，籍劳出伯劳。涉衣须计者，悬拟趁层粝。 loss:2.3054397106170654
# --- round 971 generation ---
# beautiful chinese 5 words poem:鼋籍高鞭灵，松虎细黄椓。召书海无弁，疑影轻半场。 loss:2.294431447982788
# --- round 972 generation ---
# beautiful chinese 5 words poem:锋菽步脯茄，摧用忆蜴贤。所稍漾縠望，天露留能乐。 loss:2.381390333175659
# --- round 973 generation ---
# beautiful chinese 5 words poem:滮哳重幸李，飘经忽寒寻。嘱他还熊足，际览蓑笠侣。 loss:2.321096181869507
# --- round 974 generation ---
# beautiful chinese 5 words poem:床公迎杠茄，摧床感汝壑。下手栽谁折，沙步伫狡嘉。 loss:2.355107307434082
# --- round 975 generation ---
# beautiful chinese 5 words poem:羮登罗放看，民阗困纪堂。村语紫幽啜，佳寂晓外呈。 loss:2.3911190032958984
# --- round 976 generation ---
# beautiful chinese 5 words poem:璞籍饭饧言，清寐袭翠英。执怡兼无天，留义入何洲。 loss:2.3674070835113525
# --- round 977 generation ---
# beautiful chinese 5 words poem:赖客尊迤笑，神增瘴贩。沙语歌成少，为发轸嗟遍。公 loss:2.3884260654449463
# --- round 978 generation ---
# beautiful chinese 5 words poem:响黎澎巨饯，相气访轻名。终哉罗陋息，蠢鞭黄可粮。 loss:2.240616798400879
# --- round 979 generation ---
# beautiful chinese 5 words poem:嵬绎交筵遰，殊阳戒角宅。依多走水外，置然月如过。 loss:2.3882718086242676
# --- round 980 generation ---
# beautiful chinese 5 words poem:颗木滋藓农，篱然劳寒邱。凫稻还可素，幽聚岂睡台。 loss:2.284457206726074
# --- round 981 generation ---
# beautiful chinese 5 words poem:屹登惊荒重，愿诗攒缟思。半疏观羽存，舍问分回期。 loss:2.3579654693603516
# --- round 982 generation ---
# beautiful chinese 5 words poem:儡床猥右遰，早去饧草删。顾都犹舄穴，相一许弗顾。 loss:2.4094061851501465
# --- round 983 generation ---
# beautiful chinese 5 words poem:箪待无峥暑，重时犹一名。岁游故径闲，敧蠢白年人。 loss:2.3219640254974365
# --- round 984 generation ---
# beautiful chinese 5 words poem:实莽诸功侄，陌雄浑风稀。岁生扶水坱，梅餐棹粗春。 loss:2.3849620819091797
# --- round 985 generation ---
# beautiful chinese 5 words poem:履叶伽麟涉，族用废牛足。虑策姜添之，蠢蠢只剑嘉。 loss:2.4310944080352783
# --- round 986 generation ---
# beautiful chinese 5 words poem:拟农宜田梁，野处命半蹄。誓工栽来蕊，吾口破粗衡。 loss:2.4641242027282715
# --- round 987 generation ---
# beautiful chinese 5 words poem:后竦澎望露，何时满素悭。朅息振衣日，异飓每颓日。 loss:2.54935359954834
# --- round 988 generation ---
# beautiful chinese 5 words poem:丘殇六夏斗，萧然别兰通。积性铅跽然，从能泪溪絓。 loss:2.5253710746765137
# --- round 989 generation ---
# beautiful chinese 5 words poem:习际贵架幸，依就翰卜门。放车参末议，稍骤岂时机。 loss:2.40303635597229
# --- round 990 generation ---
# beautiful chinese 5 words poem:嗜散无安展，蔬亲任相疑。蛮店阒拜教，宸麻堂莛望。 loss:2.4365642070770264
# --- round 991 generation ---
# beautiful chinese 5 words poem:资菽还脯茄，荆絙积贞嗟。竭鹤崇存议，弱代拔茅狯。 loss:2.986342668533325
# --- round 992 generation ---
# beautiful chinese 5 words poem:筱萝勿蝘蜓，民柏似吟蟷。思逵川尘伏，巴卉趣空真。 loss:3.165658950805664
# --- round 993 generation ---
# beautiful chinese 5 words poem:燔友复长笛，达舟利构聩。筹性观阶涉，桥餐受自蘀。 loss:3.732520341873169
# --- round 994 generation ---
# beautiful chinese 5 words poem:鸪辉交祖饯，荆阳旧一思。妙舟狎挞地，芳身任钓章。 loss:4.491794586181641
# --- round 995 generation ---
# beautiful chinese 5 words poem:骨时高往蔗，青青天上妙恩只至他雾凤鬼，榔州黄薤幡 loss:7.656155109405518
# --- round 996 generation ---
# beautiful chinese 5 words poem:虱触何涯冥望，清媚忆兴夷。茅意俱指屧，旷源代粗界 loss:6.568253040313721
# --- round 997 generation ---
# beautiful chinese 5 words poem:仇触心涯蛮，蔬熟照汝诸。餐。倭幼朱，孤沅醉代刀。 loss:6.24244499206543
# --- round 998 generation ---
# beautiful chinese 5 words poem:梯槛饭吾门，松醐恣鹿疆。不步鲸篔独，顿熳守须居。 loss:5.771749973297119
# --- round 999 generation ---
# beautiful chinese 5 words poem:碛者入葱李，力湖沓玉谓。筹知鳌命懒，诸蟹醉锦汇。 loss:5.5092973709106445
# --- round 1000 generation ---
# beautiful chinese 5 words poem:尝勿蓣淮出，后去珠唱翁。筹掠阒无计，况诗得上粮。 loss:4.9955830574035645

# %%
# %debug
# Out:
# > <ipython-input-195-295b1f124138>(8)acrostic_generater()
#       6   for i in range(0, 4):
#       7     word_index = word_2_index[input_text[i]]
# ----> 8     result+=imput_text[i]
#       9     for i in range(0, 7):
#      10       word_embeddings = torch.tensor(w1[word_index][None][None])
#
# ipdb> exit
